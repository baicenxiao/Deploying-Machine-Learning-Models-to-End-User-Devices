# %%
import torch
import torch.nn as nn
import numpy as np
import onnx
from onnxruntime.training import artifacts
import onnxruntime
import torch.nn.functional as F
import coremltools as ct

# %%
torch.__version__, onnx.__version__, ct.__version__, onnxruntime.__version__
# Out:
# ('2.1.0', '1.14.1', '7.1', '1.16.3')

# %%
class LSTMNumberPredictor(nn.Module):
    def __init__(self, num_classes, hidden_dim, num_layers):
        super(LSTMNumberPredictor, self).__init__()
        self.hidden_dim = hidden_dim
        self.num_layers = num_layers

        # LSTM layer
        self.lstm = nn.LSTM(input_size=1, hidden_size=hidden_dim, num_layers=num_layers, batch_first=True)
        
        # Fully connected layer
        self.fc = nn.Linear(hidden_dim, num_classes)
    
    def forward(self, x):
        # Initializing hidden state for first input
        h0 = torch.zeros(self.num_layers, x.size(0), self.hidden_dim)
        c0 = torch.zeros(self.num_layers, x.size(0), self.hidden_dim)
        
        # Forward propagate LSTM
        out, _ = self.lstm(x, (h0, c0))  # out: tensor of shape (batch_size, seq_length, hidden_dim)
        # out, _ = self.lstm(x)
        
        # Decode the hidden state of the last time step
        out = self.fc(out[:, -1, :])
        return out

# Example usage:
model = LSTMNumberPredictor(num_classes=3, hidden_dim=50, num_layers=1)

# %%
import numpy as np

def generate_training_data(data_size):
    # Generate random integers for input data X
    X = np.random.uniform(0.0, 10.0, (data_size, 6))

    # Compute output data y
    y = (np.sum(X, axis=1) / 20)
    y = y.astype(int)
    # Compute Y as the sum of each row in X divided by 3

    return torch.tensor(X, dtype=torch.float32), torch.tensor(y, dtype=torch.long)

# %%
import torch.optim as optim

# Parameters
data_size = 500  # Length of the subsequences

# Generate data
X, y = generate_training_data(data_size)

X_train = X[:400]
y_train = y[:400]
X_test = X[400:]
y_test = y[400:]

# %%
print(X[:4], y[:4])
# Out:
# tensor([[8.2320, 4.9128, 6.4885, 3.6173, 1.6645, 6.0213],
#         [4.7715, 4.0212, 8.0391, 4.3866, 7.1720, 2.0178],
#         [6.7516, 2.3123, 0.4681, 9.3191, 8.5382, 0.5726],
#         [5.9035, 8.2438, 3.2320, 0.3564, 4.8108, 8.9278]]) tensor([1, 1, 1, 1])

# %%
learning_rate = 0.001
num_epochs = 300     # Number of epochs for training


# Loss and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=learning_rate)

# %%
# Reshape input suitable for LSTM (batch_size, seq_length, input_size)
X_train = X_train.unsqueeze(-1)
X_test = X_test.unsqueeze(-1)


# Training loop
for epoch in range(num_epochs):
    model.train()
    optimizer.zero_grad()

    # Forward pass
    outputs = model(X_train)
    loss_train = criterion(outputs, y_train)

    outputs_test = model(X_test)
    loss_test = criterion(outputs_test, y_test)

    # Backward and optimize
    loss_train.backward()
    optimizer.step()

    if (epoch+1) % 100 == 0:
        print(f'Epoch [{epoch+1}/{num_epochs}], Training Loss: {loss_train.item():.4f}, Testing Loss: {loss_test.item():.4f}')
# Out:
# Epoch [100/300], Training Loss: 0.4448, Testing Loss: 0.4735
# Epoch [200/300], Training Loss: 0.1395, Testing Loss: 0.1596
# Epoch [300/300], Training Loss: 0.0622, Testing Loss: 0.0946

# %%
model.eval()

# Trace the model with random data.
example_input_for_trace = X_train[:1]

traced_model = torch.jit.trace(model, (example_input_for_trace, ))

# %%
example_input_test_trace = X_train[2:3]
out = traced_model(example_input_test_trace)
print(example_input_test_trace, out) # the first element of out is expected to have the largest value
# Out:
# tensor([[[1.5627],
#          [3.9146],
#          [6.3159],
#          [7.3567],
#          [6.9889],
#          [9.6894]]]) tensor([[-3.8410,  4.3895, -1.7654]], grad_fn=<AddmmBackward0>)

# %%
import coremltools as ct

# Using image_input in the inputs parameter:
# Convert to Core ML program using the Unified Conversion API.
model_ct = ct.convert(
    traced_model,
    # convert_to="mlprogram",
    # compute_precision=ct.precision.FLOAT32,
    inputs=[ct.TensorType(shape=example_input_for_trace.shape)],
 )

# check names of input and output
print(model_ct.input_description, model_ct.output_description)
# Out:
# 2023-12-22 17:16:58,083 coremltools [WARNING] - When both 'convert_to' and 'minimum_deployment_target' not specified, 'convert_to' is set to "mlprogram" and 'minimum_deployment_targer' is set to ct.target.iOS15 (which is same as ct.target.macOS12). Note: the model will not run on systems older than iOS15/macOS12/watchOS8/tvOS15. In order to make your model run on older system, please set the 'minimum_deployment_target' to iOS14/iOS13. Details please see the link: https://coremltools.readme.io/docs/unified-conversion-api#target-conversion-formats
# 2023-12-22 17:16:58,093 coremltools [INFO] - Converting graph.
# 2023-12-22 17:16:58,094 coremltools [INFO] - Adding op 'lstm.bias_hh_l0' of type const
# 2023-12-22 17:16:58,094 coremltools [INFO] - Adding op 'lstm.bias_ih_l0' of type const
# 2023-12-22 17:16:58,095 coremltools [INFO] - Adding op 'lstm.weight_hh_l0' of type const
# 2023-12-22 17:16:58,095 coremltools [INFO] - Adding op 'lstm.weight_ih_l0' of type const
# 2023-12-22 17:16:58,096 coremltools [INFO] - Adding op 'fc.bias' of type const
# 2023-12-22 17:16:58,097 coremltools [INFO] - Adding op 'fc.weight' of type const
# Converting PyTorch Frontend ==> MIL Ops:   0%|          | 0/45 [00:00<?, ? ops/s]2023-12-22 17:16:58,098 coremltools [INFO] - Converting op 4 : constant
# 2023-12-22 17:16:58,098 coremltools [INFO] - Adding op '4' of type const
# 2023-12-22 17:16:58,099 coremltools [INFO] - Converting op 5 : size
# 2023-12-22 17:16:58,099 coremltools [INFO] - Adding op '5_shape' of type shape
# 2023-12-22 17:16:58,100 coremltools [INFO] - Adding op 'const_0' of type const
# 2023-12-22 17:16:58,100 coremltools [INFO] - Converting op 6 : numtotensor
# 2023-12-22 17:16:58,101 coremltools [INFO] - Adding op '6' of type const
# 2023-12-22 17:16:58,101 coremltools [INFO] - Converting op 7 : int
# 2023-12-22 17:16:58,102 coremltools [INFO] - Adding op '7' of type const
# 2023-12-22 17:16:58,102 coremltools [INFO] - Converting op 8 : constant
# 2023-12-22 17:16:58,102 coremltools [INFO] - Adding op '8' of type const
# 2023-12-22 17:16:58,102 coremltools [INFO] - Converting op 9 : constant
# 2023-12-22 17:16:58,103 coremltools [INFO] - Adding op '9' of type const
# 2023-12-22 17:16:58,103 coremltools [INFO] - Converting op 10 : listconstruct
# 2023-12-22 17:16:58,104 coremltools [INFO] - Adding op '10' of type const
# 2023-12-22 17:16:58,104 coremltools [INFO] - Converting op 11 : constant
# 2023-12-22 17:16:58,104 coremltools [INFO] - Converting op 12 : constant
# 2023-12-22 17:16:58,104 coremltools [INFO] - Converting op 13 : constant
# 2023-12-22 17:16:58,104 coremltools [INFO] - Adding op '13' of type const
# 2023-12-22 17:16:58,105 coremltools [INFO] - Converting op 14 : constant
# 2023-12-22 17:16:58,105 coremltools [INFO] - Adding op '14' of type const
# 2023-12-22 17:16:58,105 coremltools [INFO] - Converting op hx.1 : zeros
# 2023-12-22 17:16:58,106 coremltools [INFO] - Adding op 'hx.1' of type const
# 2023-12-22 17:16:58,106 coremltools [INFO] - Converting op 16 : constant
# 2023-12-22 17:16:58,106 coremltools [INFO] - Adding op '16' of type const
# 2023-12-22 17:16:58,107 coremltools [INFO] - Converting op 17 : size
# 2023-12-22 17:16:58,107 coremltools [INFO] - Adding op '17_shape' of type shape
# 2023-12-22 17:16:58,107 coremltools [INFO] - Adding op 'const_1' of type const
# 2023-12-22 17:16:58,108 coremltools [INFO] - Converting op 18 : numtotensor
# 2023-12-22 17:16:58,108 coremltools [INFO] - Adding op '18' of type const
# 2023-12-22 17:16:58,108 coremltools [INFO] - Converting op 19 : int
# 2023-12-22 17:16:58,109 coremltools [INFO] - Adding op '19' of type const
# 2023-12-22 17:16:58,109 coremltools [INFO] - Converting op 20 : constant
# 2023-12-22 17:16:58,109 coremltools [INFO] - Adding op '20' of type const
# 2023-12-22 17:16:58,110 coremltools [INFO] - Converting op 21 : constant
# 2023-12-22 17:16:58,110 coremltools [INFO] - Adding op '21' of type const
# 2023-12-22 17:16:58,111 coremltools [INFO] - Converting op 22 : listconstruct
# 2023-12-22 17:16:58,111 coremltools [INFO] - Adding op '22' of type const
# 2023-12-22 17:16:58,111 coremltools [INFO] - Converting op 23 : constant
# 2023-12-22 17:16:58,111 coremltools [INFO] - Converting op 24 : constant
# 2023-12-22 17:16:58,112 coremltools [INFO] - Converting op 25 : constant
# 2023-12-22 17:16:58,112 coremltools [INFO] - Adding op '25' of type const
# 2023-12-22 17:16:58,112 coremltools [INFO] - Converting op 26 : constant
# 2023-12-22 17:16:58,113 coremltools [INFO] - Adding op '26' of type const
# 2023-12-22 17:16:58,113 coremltools [INFO] - Converting op hx : zeros
# 2023-12-22 17:16:58,113 coremltools [INFO] - Adding op 'hx' of type const
# 2023-12-22 17:16:58,114 coremltools [INFO] - Converting op 28 : constant
# 2023-12-22 17:16:58,114 coremltools [INFO] - Adding op '28' of type const
# 2023-12-22 17:16:58,114 coremltools [INFO] - Converting op 29 : constant
# 2023-12-22 17:16:58,114 coremltools [INFO] - Adding op '29' of type const
# 2023-12-22 17:16:58,115 coremltools [INFO] - Converting op 30 : constant
# 2023-12-22 17:16:58,115 coremltools [INFO] - Adding op '30' of type const
# 2023-12-22 17:16:58,115 coremltools [INFO] - Converting op 31 : constant
# 2023-12-22 17:16:58,116 coremltools [INFO] - Adding op '31' of type const
# 2023-12-22 17:16:58,116 coremltools [INFO] - Converting op 36 : listconstruct
# 2023-12-22 17:16:58,116 coremltools [INFO] - Converting op 37 : listconstruct
# 2023-12-22 17:16:58,117 coremltools [INFO] - Converting op out : lstm
# 2023-12-22 17:16:58,117 coremltools [INFO] - Adding op 'x_batch_first_transpose' of type transpose
# 2023-12-22 17:16:58,117 coremltools [DEBUG] - Adding const op 'x_batch_first_transpose_perm_0'
# 2023-12-22 17:16:58,118 coremltools [INFO] - Adding op 'x_batch_first_transpose_perm_0' of type const
# 2023-12-22 17:16:58,118 coremltools [DEBUG] - Downcast const op x_batch_first_transpose_perm_0 data int64 as int32
# 2023-12-22 17:16:58,118 coremltools [DEBUG] - Downcast const op x_batch_first_transpose_perm_0 data int64 as int32
# 2023-12-22 17:16:58,119 coremltools [INFO] - Adding op 'add_0' of type add
# 2023-12-22 17:16:58,119 coremltools [INFO] - Adding op 'split_0' of type split
# 2023-12-22 17:16:58,120 coremltools [DEBUG] - Adding const op 'split_0_split_sizes_0'
# 2023-12-22 17:16:58,120 coremltools [INFO] - Adding op 'split_0_split_sizes_0' of type const
# 2023-12-22 17:16:58,120 coremltools [DEBUG] - Downcast const op split_0_split_sizes_0 data int64 as int32
# 2023-12-22 17:16:58,120 coremltools [DEBUG] - Downcast const op split_0_split_sizes_0 data int64 as int32
# 2023-12-22 17:16:58,121 coremltools [DEBUG] - Adding const op 'split_0_axis_0'
# 2023-12-22 17:16:58,121 coremltools [INFO] - Adding op 'split_0_axis_0' of type const
# 2023-12-22 17:16:58,121 coremltools [INFO] - Adding op 'concat_0' of type concat
# 2023-12-22 17:16:58,122 coremltools [DEBUG] - Adding const op 'concat_0_axis_0'
# 2023-12-22 17:16:58,122 coremltools [INFO] - Adding op 'concat_0_axis_0' of type const
# 2023-12-22 17:16:58,122 coremltools [DEBUG] - Adding const op 'concat_0_interleave_0'
# 2023-12-22 17:16:58,123 coremltools [INFO] - Adding op 'concat_0_interleave_0' of type const
# 2023-12-22 17:16:58,123 coremltools [INFO] - Adding op 'split_1' of type split
# 2023-12-22 17:16:58,123 coremltools [DEBUG] - Adding const op 'split_1_split_sizes_0'
# 2023-12-22 17:16:58,124 coremltools [INFO] - Adding op 'split_1_split_sizes_0' of type const
# 2023-12-22 17:16:58,124 coremltools [DEBUG] - Downcast const op split_1_split_sizes_0 data int64 as int32
# 2023-12-22 17:16:58,124 coremltools [DEBUG] - Downcast const op split_1_split_sizes_0 data int64 as int32
# 2023-12-22 17:16:58,124 coremltools [DEBUG] - Adding const op 'split_1_axis_0'
# 2023-12-22 17:16:58,125 coremltools [INFO] - Adding op 'split_1_axis_0' of type const
# 2023-12-22 17:16:58,125 coremltools [INFO] - Adding op 'concat_1' of type concat
# 2023-12-22 17:16:58,126 coremltools [DEBUG] - Adding const op 'concat_1_axis_0'
# 2023-12-22 17:16:58,126 coremltools [INFO] - Adding op 'concat_1_axis_0' of type const
# 2023-12-22 17:16:58,126 coremltools [DEBUG] - Adding const op 'concat_1_interleave_0'
# 2023-12-22 17:16:58,126 coremltools [INFO] - Adding op 'concat_1_interleave_0' of type const
# 2023-12-22 17:16:58,127 coremltools [INFO] - Adding op 'split_2' of type split
# 2023-12-22 17:16:58,127 coremltools [DEBUG] - Adding const op 'split_2_split_sizes_0'
# 2023-12-22 17:16:58,127 coremltools [INFO] - Adding op 'split_2_split_sizes_0' of type const
# 2023-12-22 17:16:58,128 coremltools [DEBUG] - Downcast const op split_2_split_sizes_0 data int64 as int32
# 2023-12-22 17:16:58,128 coremltools [DEBUG] - Downcast const op split_2_split_sizes_0 data int64 as int32
# 2023-12-22 17:16:58,128 coremltools [DEBUG] - Adding const op 'split_2_axis_0'
# 2023-12-22 17:16:58,128 coremltools [INFO] - Adding op 'split_2_axis_0' of type const
# 2023-12-22 17:16:58,129 coremltools [INFO] - Adding op 'concat_2' of type concat
# 2023-12-22 17:16:58,130 coremltools [DEBUG] - Adding const op 'concat_2_axis_0'
# 2023-12-22 17:16:58,130 coremltools [INFO] - Adding op 'concat_2_axis_0' of type const
# 2023-12-22 17:16:58,130 coremltools [DEBUG] - Adding const op 'concat_2_interleave_0'
# 2023-12-22 17:16:58,131 coremltools [INFO] - Adding op 'concat_2_interleave_0' of type const
# 2023-12-22 17:16:58,131 coremltools [INFO] - Adding op 'out_batch_first_lstm_h0_squeeze' of type squeeze
# 2023-12-22 17:16:58,132 coremltools [DEBUG] - Adding const op 'out_batch_first_lstm_h0_squeeze_axes_0'
# 2023-12-22 17:16:58,132 coremltools [INFO] - Adding op 'out_batch_first_lstm_h0_squeeze_axes_0' of type const
# 2023-12-22 17:16:58,132 coremltools [DEBUG] - Downcast const op out_batch_first_lstm_h0_squeeze_axes_0 data int64 as int32
# 2023-12-22 17:16:58,132 coremltools [DEBUG] - Downcast const op out_batch_first_lstm_h0_squeeze_axes_0 data int64 as int32
# 2023-12-22 17:16:58,133 coremltools [INFO] - Adding op 'out_batch_first_lstm_c0_squeeze' of type squeeze
# 2023-12-22 17:16:58,133 coremltools [DEBUG] - Adding const op 'out_batch_first_lstm_c0_squeeze_axes_0'
# 2023-12-22 17:16:58,133 coremltools [INFO] - Adding op 'out_batch_first_lstm_c0_squeeze_axes_0' of type const
# 2023-12-22 17:16:58,133 coremltools [DEBUG] - Downcast const op out_batch_first_lstm_c0_squeeze_axes_0 data int64 as int32
# 2023-12-22 17:16:58,133 coremltools [DEBUG] - Downcast const op out_batch_first_lstm_c0_squeeze_axes_0 data int64 as int32
# 2023-12-22 17:16:58,134 coremltools [INFO] - Adding op 'out_batch_first' of type lstm
# 2023-12-22 17:16:58,134 coremltools [DEBUG] - Adding const op 'out_batch_first_direction_0'
# 2023-12-22 17:16:58,134 coremltools [INFO] - Adding op 'out_batch_first_direction_0' of type const
# 2023-12-22 17:16:58,135 coremltools [DEBUG] - Adding const op 'out_batch_first_output_sequence_0'
# 2023-12-22 17:16:58,135 coremltools [INFO] - Adding op 'out_batch_first_output_sequence_0' of type const
# 2023-12-22 17:16:58,136 coremltools [DEBUG] - Adding const op 'out_batch_first_recurrent_activation_0'
# 2023-12-22 17:16:58,136 coremltools [INFO] - Adding op 'out_batch_first_recurrent_activation_0' of type const
# 2023-12-22 17:16:58,136 coremltools [DEBUG] - Adding const op 'out_batch_first_cell_activation_0'
# 2023-12-22 17:16:58,136 coremltools [INFO] - Adding op 'out_batch_first_cell_activation_0' of type const
# 2023-12-22 17:16:58,137 coremltools [DEBUG] - Adding const op 'out_batch_first_activation_0'
# 2023-12-22 17:16:58,137 coremltools [INFO] - Adding op 'out_batch_first_activation_0' of type const
# 2023-12-22 17:16:58,138 coremltools [INFO] - Adding op 'out' of type transpose
# 2023-12-22 17:16:58,138 coremltools [DEBUG] - Adding const op 'out_perm_0'
# 2023-12-22 17:16:58,138 coremltools [INFO] - Adding op 'out_perm_0' of type const
# 2023-12-22 17:16:58,138 coremltools [DEBUG] - Downcast const op out_perm_0 data int64 as int32
# 2023-12-22 17:16:58,139 coremltools [DEBUG] - Downcast const op out_perm_0 data int64 as int32
# 2023-12-22 17:16:58,139 coremltools [INFO] - Adding op '39' of type expand_dims
# 2023-12-22 17:16:58,140 coremltools [DEBUG] - Adding const op '39_axes_0'
# 2023-12-22 17:16:58,140 coremltools [INFO] - Adding op '39_axes_0' of type const
# 2023-12-22 17:16:58,140 coremltools [DEBUG] - Downcast const op 39_axes_0 data int64 as int32
# 2023-12-22 17:16:58,140 coremltools [DEBUG] - Downcast const op 39_axes_0 data int64 as int32
# 2023-12-22 17:16:58,141 coremltools [INFO] - Adding op '40' of type expand_dims
# 2023-12-22 17:16:58,141 coremltools [DEBUG] - Adding const op '40_axes_0'
# 2023-12-22 17:16:58,141 coremltools [INFO] - Adding op '40_axes_0' of type const
# 2023-12-22 17:16:58,142 coremltools [DEBUG] - Downcast const op 40_axes_0 data int64 as int32
# 2023-12-22 17:16:58,142 coremltools [DEBUG] - Downcast const op 40_axes_0 data int64 as int32
# 2023-12-22 17:16:58,143 coremltools [INFO] - Converting op 41 : constant
# 2023-12-22 17:16:58,143 coremltools [INFO] - Adding op '41' of type const
# 2023-12-22 17:16:58,143 coremltools [INFO] - Converting op 42 : constant
# 2023-12-22 17:16:58,143 coremltools [INFO] - Adding op '42' of type const
# 2023-12-22 17:16:58,144 coremltools [INFO] - Converting op 43 : constant
# 2023-12-22 17:16:58,144 coremltools [INFO] - Converting op 44 : constant
# 2023-12-22 17:16:58,145 coremltools [INFO] - Adding op '44' of type const
# 2023-12-22 17:16:58,145 coremltools [INFO] - Converting op 45 : slice
# 2023-12-22 17:16:58,145 coremltools [INFO] - Converting op 46 : constant
# 2023-12-22 17:16:58,146 coremltools [INFO] - Adding op '46' of type const
# 2023-12-22 17:16:58,146 coremltools [INFO] - Converting op 47 : constant
# 2023-12-22 17:16:58,146 coremltools [INFO] - Adding op '47' of type const
# 2023-12-22 17:16:58,147 coremltools [INFO] - Converting op 48 : select
# 2023-12-22 17:16:58,147 coremltools [INFO] - Adding op '48' of type slice_by_index
# 2023-12-22 17:16:58,147 coremltools [DEBUG] - Adding const op '48_begin_0'
# 2023-12-22 17:16:58,148 coremltools [INFO] - Adding op '48_begin_0' of type const
# 2023-12-22 17:16:58,148 coremltools [DEBUG] - Downcast const op 48_begin_0 data int64 as int32
# 2023-12-22 17:16:58,148 coremltools [DEBUG] - Downcast const op 48_begin_0 data int64 as int32
# 2023-12-22 17:16:58,149 coremltools [DEBUG] - Adding const op '48_end_0'
# 2023-12-22 17:16:58,149 coremltools [INFO] - Adding op '48_end_0' of type const
# 2023-12-22 17:16:58,149 coremltools [DEBUG] - Downcast const op 48_end_0 data int64 as int32
# 2023-12-22 17:16:58,150 coremltools [DEBUG] - Downcast const op 48_end_0 data int64 as int32
# 2023-12-22 17:16:58,150 coremltools [DEBUG] - Adding const op '48_end_mask_0'
# 2023-12-22 17:16:58,151 coremltools [INFO] - Adding op '48_end_mask_0' of type const
# 2023-12-22 17:16:58,151 coremltools [DEBUG] - Adding const op '48_squeeze_mask_0'
# 2023-12-22 17:16:58,151 coremltools [INFO] - Adding op '48_squeeze_mask_0' of type const
# 2023-12-22 17:16:58,152 coremltools [INFO] - Converting op 49 : constant
# 2023-12-22 17:16:58,155 coremltools [INFO] - Adding op '49' of type const
# 2023-12-22 17:16:58,158 coremltools [INFO] - Converting op 50 : constant
# 2023-12-22 17:16:58,165 coremltools [INFO] - Adding op '50' of type const
# 2023-12-22 17:16:58,170 coremltools [INFO] - Converting op 51 : constant
# 2023-12-22 17:16:58,173 coremltools [INFO] - Converting op 52 : constant
# 2023-12-22 17:16:58,175 coremltools [INFO] - Adding op '52' of type const
# 2023-12-22 17:16:58,177 coremltools [INFO] - Converting op input : slice
# 2023-12-22 17:16:58,178 coremltools [INFO] - Converting op 56 : linear
# 2023-12-22 17:16:58,179 coremltools [INFO] - Adding op 'linear_0' of type linear
# Converting PyTorch Frontend ==> MIL Ops:  98%|█████████▊| 44/45 [00:00<00:00, 533.97 ops/s]
# 2023-12-22 17:16:58,182 coremltools [DEBUG] - Program before frontend_pytorch pipeline:
# main[CoreML5](%x: (1, 6, 1, fp32)(Tensor)) {
#   block5() {
#     %5_shape: (3,int32)*(Tensor) = shape(x=%x, name="5_shape")
#     %17_shape: (3,int32)*(Tensor) = shape(x=%x, name="17_shape")
#     %x_batch_first_transpose: (6, 1, 1, fp32)(Tensor) = transpose(x=%x, perm=[1, 0, 2], name="x_batch_first_transpose")
#     %add_0: (200,fp32)*(Tensor) = add(x=%lstm.bias_ih_l0, y=%lstm.bias_hh_l0, name="add_0")
#     %split_0_0: (50,fp32)*(Tensor), %split_0_1: (50,fp32)*(Tensor), %split_0_2: (50,fp32)*(Tensor), %split_0_3: (50,fp32)*(Tensor) = split(x=%add_0, split_sizes=[50, 50, 50, 50], axis=0, name="split_0")
#     %concat_0: (200,fp32)*(Tensor) = concat(values=(%split_0_0, %split_0_1, %split_0_3, %split_0_2), axis=0, interleave=False, name="concat_0")
#     %split_1_0: (50, 1, fp32)*(Tensor), %split_1_1: (50, 1, fp32)*(Tensor), %split_1_2: (50, 1, fp32)*(Tensor), %split_1_3: (50, 1, fp32)*(Tensor) = split(x=%lstm.weight_ih_l0, split_sizes=[50, 50, 50, 50], axis=0, name="split_1")
#     %concat_1: (200, 1, fp32)*(Tensor) = concat(values=(%split_1_0, %split_1_1, %split_1_3, %split_1_2), axis=0, interleave=False, name="concat_1")
#     %split_2_0: (50, 50, fp32)*(Tensor), %split_2_1: (50, 50, fp32)*(Tensor), %split_2_2: (50, 50, fp32)*(Tensor), %split_2_3: (50, 50, fp32)*(Tensor) = split(x=%lstm.weight_hh_l0, split_sizes=[50, 50, 50, 50], axis=0, name="split_2")
#     %concat_2: (200, 50, fp32)*(Tensor) = concat(values=(%split_2_0, %split_2_1, %split_2_3, %split_2_2), axis=0, interleave=False, name="concat_2")
#     %out_batch_first_lstm_h0_squeeze: (1, 50, fp32)*(Tensor) = squeeze(x=%hx.1, axes=[0], name="out_batch_first_lstm_h0_squeeze")
#     %out_batch_first_lstm_c0_squeeze: (1, 50, fp32)*(Tensor) = squeeze(x=%hx, axes=[0], name="out_batch_first_lstm_c0_squeeze")
#     %out_batch_first_0: (6, 1, 50, fp32)(Tensor), %out_batch_first_1: (1, 50, fp32)(Tensor), %out_batch_first_2: (1, 50, fp32)(Tensor) = lstm(x=%x_batch_first_transpose, initial_h=%out_batch_first_lstm_h0_squeeze, initial_c=%out_batch_first_lstm_c0_squeeze, weight_ih=%concat_1, weight_hh=%concat_2, bias=%concat_0, direction="forward", output_sequence=True, recurrent_activation="sigmoid", cell_activation="tanh", activation="tanh", name="out_batch_first")
#     %out: (1, 6, 50, fp32)(Tensor) = transpose(x=%out_batch_first_0, perm=[1, 0, 2], name="out")
#     %39: (1, 1, 50, fp32)(Tensor) = expand_dims(x=%out_batch_first_1, axes=[0], name="39")
#     %40: (1, 1, 50, fp32)(Tensor) = expand_dims(x=%out_batch_first_2, axes=[0], name="40")
#     %48: (1, 50, fp32)(Tensor) = slice_by_index(x=%out, begin=[0, -1, 0], end=[1, 6, 50], end_mask=[True, True, True], squeeze_mask=[False, True, False], name="48")
#     %linear_0: (1, 3, fp32)(Tensor) = linear(x=%48, weight=%fc.weight, bias=[0.07220993936061859, -0.009139922447502613, -0.10473349690437317], name="linear_0")
#   } -> (%linear_0)
# }
#
# Running MIL frontend_pytorch pipeline:   0%|          | 0/5 [00:00<?, ? passes/s]2023-12-22 17:16:58,183 coremltools [INFO] - Performing pass: "common::dead_code_elimination"
# 2023-12-22 17:16:58,183 coremltools [INFO] - Removing op "52" (type: const)
# 2023-12-22 17:16:58,183 coremltools [INFO] - Removing op "50" (type: const)
# 2023-12-22 17:16:58,184 coremltools [INFO] - Removing op "49" (type: const)
# 2023-12-22 17:16:58,184 coremltools [INFO] - Removing op "47" (type: const)
# 2023-12-22 17:16:58,184 coremltools [INFO] - Removing op "46" (type: const)
# 2023-12-22 17:16:58,185 coremltools [INFO] - Removing op "44" (type: const)
# 2023-12-22 17:16:58,185 coremltools [INFO] - Removing op "42" (type: const)
# 2023-12-22 17:16:58,185 coremltools [INFO] - Removing op "41" (type: const)
# 2023-12-22 17:16:58,186 coremltools [INFO] - Removing op "40" (type: expand_dims)
# 2023-12-22 17:16:58,186 coremltools [INFO] - Removing op "40_axes_0" (type: const)
# 2023-12-22 17:16:58,186 coremltools [INFO] - Removing op "39" (type: expand_dims)
# 2023-12-22 17:16:58,186 coremltools [INFO] - Removing op "39_axes_0" (type: const)
# 2023-12-22 17:16:58,187 coremltools [INFO] - Removing op "31" (type: const)
# 2023-12-22 17:16:58,187 coremltools [INFO] - Removing op "30" (type: const)
# 2023-12-22 17:16:58,187 coremltools [INFO] - Removing op "29" (type: const)
# 2023-12-22 17:16:58,187 coremltools [INFO] - Removing op "28" (type: const)
# 2023-12-22 17:16:58,188 coremltools [INFO] - Removing op "26" (type: const)
# 2023-12-22 17:16:58,188 coremltools [INFO] - Removing op "25" (type: const)
# 2023-12-22 17:16:58,188 coremltools [INFO] - Removing op "22" (type: const)
# 2023-12-22 17:16:58,189 coremltools [INFO] - Removing op "21" (type: const)
# 2023-12-22 17:16:58,189 coremltools [INFO] - Removing op "20" (type: const)
# 2023-12-22 17:16:58,189 coremltools [INFO] - Removing op "19" (type: const)
# 2023-12-22 17:16:58,189 coremltools [INFO] - Removing op "18" (type: const)
# 2023-12-22 17:16:58,190 coremltools [INFO] - Removing op "const_1" (type: const)
# 2023-12-22 17:16:58,190 coremltools [INFO] - Removing op "17_shape" (type: shape)
# 2023-12-22 17:16:58,190 coremltools [INFO] - Removing op "16" (type: const)
# 2023-12-22 17:16:58,190 coremltools [INFO] - Removing op "14" (type: const)
# 2023-12-22 17:16:58,191 coremltools [INFO] - Removing op "13" (type: const)
# 2023-12-22 17:16:58,191 coremltools [INFO] - Removing op "10" (type: const)
# 2023-12-22 17:16:58,192 coremltools [INFO] - Removing op "9" (type: const)
# 2023-12-22 17:16:58,192 coremltools [INFO] - Removing op "8" (type: const)
# 2023-12-22 17:16:58,192 coremltools [INFO] - Removing op "7" (type: const)
# 2023-12-22 17:16:58,193 coremltools [INFO] - Removing op "6" (type: const)
# 2023-12-22 17:16:58,193 coremltools [INFO] - Removing op "const_0" (type: const)
# 2023-12-22 17:16:58,194 coremltools [INFO] - Removing op "5_shape" (type: shape)
# 2023-12-22 17:16:58,194 coremltools [INFO] - Removing op "4" (type: const)
# 2023-12-22 17:16:58,195 coremltools [INFO] - Performing pass: "common::loop_invariant_elimination"
# 2023-12-22 17:16:58,195 coremltools [INFO] - Performing pass: "common::dead_code_elimination"
# 2023-12-22 17:16:58,196 coremltools [INFO] - Performing pass: "torch::torch_upsample_to_core_upsample"
# 2023-12-22 17:16:58,196 coremltools [INFO] - Performing pass: "torch::torch_tensor_assign_to_core"
# Running MIL frontend_pytorch pipeline: 100%|██████████| 5/5 [00:00<00:00, 355.85 passes/s]
# 2023-12-22 17:16:58,198 coremltools [DEBUG] - Program after frontend_pytorch pipeline:
# main[CoreML5](%x: (1, 6, 1, fp32)(Tensor)) {
#   block5() {
#     %x_batch_first_transpose: (6, 1, 1, fp32)(Tensor) = transpose(x=%x, perm=[1, 0, 2], name="x_batch_first_transpose")
#     %add_0: (200,fp32)*(Tensor) = add(x=%lstm.bias_ih_l0, y=%lstm.bias_hh_l0, name="add_0")
#     %split_0_0: (50,fp32)*(Tensor), %split_0_1: (50,fp32)*(Tensor), %split_0_2: (50,fp32)*(Tensor), %split_0_3: (50,fp32)*(Tensor) = split(x=%add_0, split_sizes=[50, 50, 50, 50], axis=0, name="split_0")
#     %concat_0: (200,fp32)*(Tensor) = concat(values=(%split_0_0, %split_0_1, %split_0_3, %split_0_2), axis=0, interleave=False, name="concat_0")
#     %split_1_0: (50, 1, fp32)*(Tensor), %split_1_1: (50, 1, fp32)*(Tensor), %split_1_2: (50, 1, fp32)*(Tensor), %split_1_3: (50, 1, fp32)*(Tensor) = split(x=%lstm.weight_ih_l0, split_sizes=[50, 50, 50, 50], axis=0, name="split_1")
#     %concat_1: (200, 1, fp32)*(Tensor) = concat(values=(%split_1_0, %split_1_1, %split_1_3, %split_1_2), axis=0, interleave=False, name="concat_1")
#     %split_2_0: (50, 50, fp32)*(Tensor), %split_2_1: (50, 50, fp32)*(Tensor), %split_2_2: (50, 50, fp32)*(Tensor), %split_2_3: (50, 50, fp32)*(Tensor) = split(x=%lstm.weight_hh_l0, split_sizes=[50, 50, 50, 50], axis=0, name="split_2")
#     %concat_2: (200, 50, fp32)*(Tensor) = concat(values=(%split_2_0, %split_2_1, %split_2_3, %split_2_2), axis=0, interleave=False, name="concat_2")
#     %out_batch_first_lstm_h0_squeeze: (1, 50, fp32)*(Tensor) = squeeze(x=%hx.1, axes=[0], name="out_batch_first_lstm_h0_squeeze")
#     %out_batch_first_lstm_c0_squeeze: (1, 50, fp32)*(Tensor) = squeeze(x=%hx, axes=[0], name="out_batch_first_lstm_c0_squeeze")
#     %out_batch_first_0: (6, 1, 50, fp32)(Tensor), %out_batch_first_1: (1, 50, fp32)(Tensor), %out_batch_first_2: (1, 50, fp32)(Tensor) = lstm(x=%x_batch_first_transpose, initial_h=%out_batch_first_lstm_h0_squeeze, initial_c=%out_batch_first_lstm_c0_squeeze, weight_ih=%concat_1, weight_hh=%concat_2, bias=%concat_0, direction="forward", output_sequence=True, recurrent_activation="sigmoid", cell_activation="tanh", activation="tanh", name="out_batch_first")
#     %out: (1, 6, 50, fp32)(Tensor) = transpose(x=%out_batch_first_0, perm=[1, 0, 2], name="out")
#     %48: (1, 50, fp32)(Tensor) = slice_by_index(x=%out, begin=[0, -1, 0], end=[1, 6, 50], end_mask=[True, True, True], squeeze_mask=[False, True, False], name="48")
#     %linear_0: (1, 3, fp32)(Tensor) = linear(x=%48, weight=%fc.weight, bias=[0.07220993936061859, -0.009139922447502613, -0.10473349690437317], name="linear_0")
#   } -> (%linear_0)
# }
#
# 2023-12-22 17:16:58,198 coremltools [DEBUG] - Program before default pipeline:
# main[CoreML5](%x: (1, 6, 1, fp32)(Tensor)) {
#   block5() {
#     %x_batch_first_transpose: (6, 1, 1, fp32)(Tensor) = transpose(x=%x, perm=[1, 0, 2], name="x_batch_first_transpose")
#     %add_0: (200,fp32)*(Tensor) = add(x=%lstm.bias_ih_l0, y=%lstm.bias_hh_l0, name="add_0")
#     %split_0_0: (50,fp32)*(Tensor), %split_0_1: (50,fp32)*(Tensor), %split_0_2: (50,fp32)*(Tensor), %split_0_3: (50,fp32)*(Tensor) = split(x=%add_0, split_sizes=[50, 50, 50, 50], axis=0, name="split_0")
#     %concat_0: (200,fp32)*(Tensor) = concat(values=(%split_0_0, %split_0_1, %split_0_3, %split_0_2), axis=0, interleave=False, name="concat_0")
#     %split_1_0: (50, 1, fp32)*(Tensor), %split_1_1: (50, 1, fp32)*(Tensor), %split_1_2: (50, 1, fp32)*(Tensor), %split_1_3: (50, 1, fp32)*(Tensor) = split(x=%lstm.weight_ih_l0, split_sizes=[50, 50, 50, 50], axis=0, name="split_1")
#     %concat_1: (200, 1, fp32)*(Tensor) = concat(values=(%split_1_0, %split_1_1, %split_1_3, %split_1_2), axis=0, interleave=False, name="concat_1")
#     %split_2_0: (50, 50, fp32)*(Tensor), %split_2_1: (50, 50, fp32)*(Tensor), %split_2_2: (50, 50, fp32)*(Tensor), %split_2_3: (50, 50, fp32)*(Tensor) = split(x=%lstm.weight_hh_l0, split_sizes=[50, 50, 50, 50], axis=0, name="split_2")
#     %concat_2: (200, 50, fp32)*(Tensor) = concat(values=(%split_2_0, %split_2_1, %split_2_3, %split_2_2), axis=0, interleave=False, name="concat_2")
#     %out_batch_first_lstm_h0_squeeze: (1, 50, fp32)*(Tensor) = squeeze(x=%hx.1, axes=[0], name="out_batch_first_lstm_h0_squeeze")
#     %out_batch_first_lstm_c0_squeeze: (1, 50, fp32)*(Tensor) = squeeze(x=%hx, axes=[0], name="out_batch_first_lstm_c0_squeeze")
#     %out_batch_first_0: (6, 1, 50, fp32)(Tensor), %out_batch_first_1: (1, 50, fp32)(Tensor), %out_batch_first_2: (1, 50, fp32)(Tensor) = lstm(x=%x_batch_first_transpose, initial_h=%out_batch_first_lstm_h0_squeeze, initial_c=%out_batch_first_lstm_c0_squeeze, weight_ih=%concat_1, weight_hh=%concat_2, bias=%concat_0, direction="forward", output_sequence=True, recurrent_activation="sigmoid", cell_activation="tanh", activation="tanh", name="out_batch_first")
#     %out: (1, 6, 50, fp32)(Tensor) = transpose(x=%out_batch_first_0, perm=[1, 0, 2], name="out")
#     %48: (1, 50, fp32)(Tensor) = slice_by_index(x=%out, begin=[0, -1, 0], end=[1, 6, 50], end_mask=[True, True, True], squeeze_mask=[False, True, False], name="48")
#     %linear_0: (1, 3, fp32)(Tensor) = linear(x=%48, weight=%fc.weight, bias=[0.07220993936061859, -0.009139922447502613, -0.10473349690437317], name="linear_0")
#   } -> (%linear_0)
# }
#
# Running MIL default pipeline:   0%|          | 0/71 [00:00<?, ? passes/s]2023-12-22 17:16:58,200 coremltools [INFO] - Performing pass: "common::lower_complex_dialect_ops"
# 2023-12-22 17:16:58,201 coremltools [INFO] - Performing pass: "common::update_output_dtypes"
# 2023-12-22 17:16:58,201 coremltools [INFO] - Performing pass: "common::cast_optimization"
# 2023-12-22 17:16:58,202 coremltools [INFO] - Performing pass: "common::noop_elimination"
# 2023-12-22 17:16:58,202 coremltools [INFO] - Performing pass: "common::int_op_canonicalization"
# 2023-12-22 17:16:58,203 coremltools [INFO] - Performing pass: "common::nullify_redundant_quantization_zero_point"
# 2023-12-22 17:16:58,203 coremltools [INFO] - Performing pass: "common::dequantize_quantize_pair_elimination"
# 2023-12-22 17:16:58,203 coremltools [INFO] - Performing pass: "common::distributive_quantized_binary_op_scale_normalization"
# 2023-12-22 17:16:58,204 coremltools [INFO] - Performing pass: "common::dequantize_to_constexpr"
# 2023-12-22 17:16:58,204 coremltools [INFO] - Performing pass: "common::const_elimination"
# 2023-12-22 17:16:58,205 coremltools [INFO] - Adding op 'add_0' of type const
# 2023-12-22 17:16:58,205 coremltools [DEBUG] - Num ops affected in replacing var: 1
# 2023-12-22 17:16:58,205 coremltools [INFO] - Adding op 'split_0_0' of type const
# 2023-12-22 17:16:58,206 coremltools [DEBUG] - Num ops affected in replacing var: 1
# 2023-12-22 17:16:58,206 coremltools [INFO] - Adding op 'split_0_1' of type const
# 2023-12-22 17:16:58,207 coremltools [DEBUG] - Num ops affected in replacing var: 1
# 2023-12-22 17:16:58,207 coremltools [INFO] - Adding op 'split_0_2' of type const
# 2023-12-22 17:16:58,207 coremltools [DEBUG] - Num ops affected in replacing var: 1
# 2023-12-22 17:16:58,208 coremltools [INFO] - Adding op 'split_0_3' of type const
# 2023-12-22 17:16:58,208 coremltools [DEBUG] - Num ops affected in replacing var: 1
# 2023-12-22 17:16:58,208 coremltools [INFO] - Adding op 'concat_0' of type const
# 2023-12-22 17:16:58,209 coremltools [DEBUG] - Num ops affected in replacing var: 1
# 2023-12-22 17:16:58,209 coremltools [INFO] - Adding op 'split_1_0' of type const
# 2023-12-22 17:16:58,210 coremltools [DEBUG] - Num ops affected in replacing var: 1
# 2023-12-22 17:16:58,210 coremltools [INFO] - Adding op 'split_1_1' of type const
# 2023-12-22 17:16:58,210 coremltools [DEBUG] - Num ops affected in replacing var: 1
# 2023-12-22 17:16:58,210 coremltools [INFO] - Adding op 'split_1_2' of type const
# 2023-12-22 17:16:58,211 coremltools [DEBUG] - Num ops affected in replacing var: 1
# 2023-12-22 17:16:58,211 coremltools [INFO] - Adding op 'split_1_3' of type const
# 2023-12-22 17:16:58,211 coremltools [DEBUG] - Num ops affected in replacing var: 1
# 2023-12-22 17:16:58,211 coremltools [INFO] - Adding op 'concat_1' of type const
# 2023-12-22 17:16:58,212 coremltools [DEBUG] - Num ops affected in replacing var: 1
# 2023-12-22 17:16:58,212 coremltools [INFO] - Adding op 'split_2_0' of type const
# 2023-12-22 17:16:58,212 coremltools [DEBUG] - Num ops affected in replacing var: 1
# 2023-12-22 17:16:58,213 coremltools [INFO] - Adding op 'split_2_1' of type const
# 2023-12-22 17:16:58,213 coremltools [DEBUG] - Num ops affected in replacing var: 1
# 2023-12-22 17:16:58,213 coremltools [INFO] - Adding op 'split_2_2' of type const
# 2023-12-22 17:16:58,214 coremltools [DEBUG] - Num ops affected in replacing var: 1
# 2023-12-22 17:16:58,214 coremltools [INFO] - Adding op 'split_2_3' of type const
# 2023-12-22 17:16:58,214 coremltools [DEBUG] - Num ops affected in replacing var: 1
# 2023-12-22 17:16:58,215 coremltools [INFO] - Adding op 'concat_2' of type const
# 2023-12-22 17:16:58,215 coremltools [DEBUG] - Num ops affected in replacing var: 1
# 2023-12-22 17:16:58,215 coremltools [INFO] - Adding op 'out_batch_first_lstm_h0_squeeze' of type const
# 2023-12-22 17:16:58,217 coremltools [DEBUG] - Num ops affected in replacing var: 1
# 2023-12-22 17:16:58,217 coremltools [INFO] - Adding op 'out_batch_first_lstm_c0_squeeze' of type const
# 2023-12-22 17:16:58,217 coremltools [DEBUG] - Num ops affected in replacing var: 1
# 2023-12-22 17:16:58,218 coremltools [INFO] - Performing pass: "common::sanitize_input_output_names"
# 2023-12-22 17:16:58,218 coremltools [INFO] - Performing pass: "common::divide_to_multiply"
# 2023-12-22 17:16:58,218 coremltools [INFO] - Performing pass: "common::select_optimization"
# 2023-12-22 17:16:58,218 coremltools [INFO] - Performing pass: "common::add_conv_transpose_output_shape"
# 2023-12-22 17:16:58,219 coremltools [INFO] - Performing pass: "common::const_elimination"
# 2023-12-22 17:16:58,219 coremltools [INFO] - Performing pass: "common::const_deduplication"
# 2023-12-22 17:16:58,220 coremltools [INFO] - Performing pass: "common::loop_invariant_elimination"
# 2023-12-22 17:16:58,221 coremltools [INFO] - Performing pass: "common::remove_symbolic_reshape"
# 2023-12-22 17:16:58,221 coremltools [INFO] - remove_symbolic_reshape: changed 0 reshapes.
# 2023-12-22 17:16:58,222 coremltools [INFO] - Performing pass: "common::noop_elimination"
# 2023-12-22 17:16:58,222 coremltools [INFO] - Performing pass: "common::fuse_matmul_weight_bias"
# 2023-12-22 17:16:58,222 coremltools [INFO] - Performing pass: "common::fuse_linear_bias"
# 2023-12-22 17:16:58,223 coremltools [INFO] - Performing pass: "common::fuse_gelu_tanh_approximation"
# 2023-12-22 17:16:58,224 coremltools [INFO] - Adding op 'pow' of type pow
# 2023-12-22 17:16:58,224 coremltools [DEBUG] - Adding const op 'pow_y_0'
# 2023-12-22 17:16:58,225 coremltools [INFO] - Adding op 'pow_y_0' of type const
# 2023-12-22 17:16:58,225 coremltools [INFO] - Adding op 'mul_1' of type mul
# 2023-12-22 17:16:58,225 coremltools [DEBUG] - Adding const op 'mul_1_x_0'
# 2023-12-22 17:16:58,226 coremltools [INFO] - Adding op 'mul_1_x_0' of type const
# 2023-12-22 17:16:58,226 coremltools [INFO] - Adding op 'add' of type add
# 2023-12-22 17:16:58,226 coremltools [INFO] - Adding op 'mul_2' of type mul
# 2023-12-22 17:16:58,227 coremltools [DEBUG] - Adding const op 'mul_2_x_0'
# 2023-12-22 17:16:58,227 coremltools [INFO] - Adding op 'mul_2_x_0' of type const
# 2023-12-22 17:16:58,227 coremltools [INFO] - Adding op 'tanh' of type tanh
# 2023-12-22 17:16:58,229 coremltools [INFO] - Adding op 'add_1' of type add
# 2023-12-22 17:16:58,230 coremltools [DEBUG] - Adding const op 'add_1_x_0'
# 2023-12-22 17:16:58,231 coremltools [INFO] - Adding op 'add_1_x_0' of type const
# 2023-12-22 17:16:58,232 coremltools [INFO] - Adding op 'mul' of type mul
# 2023-12-22 17:16:58,233 coremltools [DEBUG] - Adding const op 'mul_x_0'
# 2023-12-22 17:16:58,234 coremltools [INFO] - Adding op 'mul_x_0' of type const
# 2023-12-22 17:16:58,235 coremltools [INFO] - Adding op 'mul_3' of type mul
# 2023-12-22 17:16:58,236 coremltools [INFO] - Adding op 'pow' of type pow
# 2023-12-22 17:16:58,237 coremltools [DEBUG] - Adding const op 'pow_y_1'
# 2023-12-22 17:16:58,242 coremltools [INFO] - Adding op 'pow_y_1' of type const
# 2023-12-22 17:16:58,243 coremltools [INFO] - Adding op 'mul_1' of type mul
# 2023-12-22 17:16:58,245 coremltools [DEBUG] - Adding const op 'mul_1_x_1'
# 2023-12-22 17:16:58,247 coremltools [INFO] - Adding op 'mul_1_x_1' of type const
# 2023-12-22 17:16:58,249 coremltools [INFO] - Adding op 'add' of type add
# 2023-12-22 17:16:58,250 coremltools [INFO] - Adding op 'mul_2' of type mul
# 2023-12-22 17:16:58,252 coremltools [DEBUG] - Adding const op 'mul_2_x_1'
# 2023-12-22 17:16:58,253 coremltools [INFO] - Adding op 'mul_2_x_1' of type const
# 2023-12-22 17:16:58,253 coremltools [INFO] - Adding op 'tanh' of type tanh
# 2023-12-22 17:16:58,253 coremltools [INFO] - Adding op 'add_1' of type add
# 2023-12-22 17:16:58,253 coremltools [DEBUG] - Adding const op 'add_1_x_1'
# 2023-12-22 17:16:58,254 coremltools [INFO] - Adding op 'add_1_x_1' of type const
# 2023-12-22 17:16:58,254 coremltools [INFO] - Adding op 'mul' of type mul
# 2023-12-22 17:16:58,255 coremltools [DEBUG] - Adding const op 'mul_x_1'
# 2023-12-22 17:16:58,255 coremltools [INFO] - Adding op 'mul_x_1' of type const
# 2023-12-22 17:16:58,256 coremltools [INFO] - Adding op 'mul_3' of type mul
# 2023-12-22 17:16:58,256 coremltools [INFO] - Performing pass: "common::fuse_gelu_exact"
# 2023-12-22 17:16:58,257 coremltools [INFO] - Performing pass: "common::fuse_leaky_relu"
# 2023-12-22 17:16:58,257 coremltools [INFO] - Performing pass: "common::rank0_expand_dims_swap"
# 2023-12-22 17:16:58,257 coremltools [INFO] - Performing pass: "common::fuse_squeeze_expand_dims"
# 2023-12-22 17:16:58,258 coremltools [INFO] - Performing pass: "common::compose_conv1d"
# 2023-12-22 17:16:58,258 coremltools [INFO] - Performing pass: "common::use_reflection_padding"
# 2023-12-22 17:16:58,259 coremltools [INFO] - Performing pass: "common::merge_consecutive_paddings"
# 2023-12-22 17:16:58,259 coremltools [INFO] - Performing pass: "common::fuse_pad_conv"
# 2023-12-22 17:16:58,260 coremltools [INFO] - Performing pass: "common::image_input_preprocess"
# 2023-12-22 17:16:58,261 coremltools [INFO] - Performing pass: "common::replace_stack_reshape"
# 2023-12-22 17:16:58,261 coremltools [INFO] - Performing pass: "common::reduce_transposes"
# 2023-12-22 17:16:58,261 coremltools [INFO] - Adding op 'identity_0' of type identity
# 2023-12-22 17:16:58,262 coremltools [DEBUG] - Block before optimize transpose transform:
# function[CoreML5](%x: (1, 6, 1, fp32)(Tensor)) {
#   block5() {
#     %x_batch_first_transpose: (6, 1, 1, fp32)(Tensor) = transpose(x=%x, perm=[1, 0, 2], name="x_batch_first_transpose")
#     %out_batch_first_0: (6, 1, 50, fp32)(Tensor), %out_batch_first_1: (1, 50, fp32)(Tensor), %out_batch_first_2: (1, 50, fp32)(Tensor) = lstm(x=%x_batch_first_transpose, initial_h=%out_batch_first_lstm_h0_squeeze, initial_c=%out_batch_first_lstm_c0_squeeze, weight_ih=%concat_1, weight_hh=%concat_2, bias=%concat_0, direction="forward", output_sequence=True, recurrent_activation="sigmoid", cell_activation="tanh", activation="tanh", name="out_batch_first")
#     %out: (1, 6, 50, fp32)(Tensor) = transpose(x=%out_batch_first_0, perm=[1, 0, 2], name="out")
#     %48: (1, 50, fp32)(Tensor) = slice_by_index(x=%out, begin=[0, -1, 0], end=[1, 6, 50], end_mask=[True, True, True], squeeze_mask=[False, True, False], name="48")
#     %linear_0: (1, 3, fp32)(Tensor) = linear(x=%48, weight=%fc.weight, bias=[0.07220993936061859, -0.009139922447502613, -0.10473349690437317], name="linear_0")
#     %identity_0: (1, 3, fp32)(Tensor) = identity(x=%linear_0, name="identity_0")
#   } -> (%identity_0)
# }
#
# 2023-12-22 17:16:58,263 coremltools [DEBUG] - Block after optimize transpose transform:
# function[CoreML5](%x: (1, 6, 1, fp32)(Tensor)) {
#   block5() {
#     %x_batch_first_transpose: (6, 1, 1, fp32)(Tensor) = transpose(x=%x, perm=[1, 0, 2], name="x_batch_first_transpose")
#     %out_batch_first_0: (6, 1, 50, fp32)(Tensor), %out_batch_first_1: (1, 50, fp32)(Tensor), %out_batch_first_2: (1, 50, fp32)(Tensor) = lstm(x=%x_batch_first_transpose, initial_h=%out_batch_first_lstm_h0_squeeze, initial_c=%out_batch_first_lstm_c0_squeeze, weight_ih=%concat_1, weight_hh=%concat_2, bias=%concat_0, direction="forward", output_sequence=True, recurrent_activation="sigmoid", cell_activation="tanh", activation="tanh", name="out_batch_first")
#     %out: (1, 6, 50, fp32)(Tensor) = transpose(x=%out_batch_first_0, perm=[1, 0, 2], name="out")
#     %48: (1, 50, fp32)(Tensor) = slice_by_index(x=%out, begin=[0, -1, 0], end=[1, 6, 50], end_mask=[True, True, True], squeeze_mask=[False, True, False], name="48")
#     %linear_0: (1, 3, fp32)(Tensor) = linear(x=%48, weight=%fc.weight, bias=[0.07220993936061859, -0.009139922447502613, -0.10473349690437317], name="linear_0")
#   } -> (%linear_0)
# }
#
# 2023-12-22 17:16:58,264 coremltools [DEBUG] - Downcast const op x_batch_first_transpose_perm_0 data int64 as int32
# 2023-12-22 17:16:58,264 coremltools [DEBUG] - Downcast const op x_batch_first_transpose_perm_0 data int64 as int32
# 2023-12-22 17:16:58,265 coremltools [DEBUG] - Downcast const op split_0_split_sizes_0 data int64 as int32
# 2023-12-22 17:16:58,265 coremltools [DEBUG] - Downcast const op split_0_split_sizes_0 data int64 as int32
# 2023-12-22 17:16:58,266 coremltools [DEBUG] - Downcast const op split_1_split_sizes_0 data int64 as int32
# 2023-12-22 17:16:58,266 coremltools [DEBUG] - Downcast const op split_1_split_sizes_0 data int64 as int32
# 2023-12-22 17:16:58,267 coremltools [DEBUG] - Downcast const op split_2_split_sizes_0 data int64 as int32
# 2023-12-22 17:16:58,267 coremltools [DEBUG] - Downcast const op split_2_split_sizes_0 data int64 as int32
# 2023-12-22 17:16:58,268 coremltools [DEBUG] - Downcast const op out_batch_first_lstm_h0_squeeze_axes_0 data int64 as int32
# 2023-12-22 17:16:58,268 coremltools [DEBUG] - Downcast const op out_batch_first_lstm_h0_squeeze_axes_0 data int64 as int32
# 2023-12-22 17:16:58,268 coremltools [DEBUG] - Downcast const op out_batch_first_lstm_c0_squeeze_axes_0 data int64 as int32
# 2023-12-22 17:16:58,268 coremltools [DEBUG] - Downcast const op out_batch_first_lstm_c0_squeeze_axes_0 data int64 as int32
# 2023-12-22 17:16:58,269 coremltools [DEBUG] - Downcast const op out_perm_0 data int64 as int32
# 2023-12-22 17:16:58,269 coremltools [DEBUG] - Downcast const op out_perm_0 data int64 as int32
# 2023-12-22 17:16:58,269 coremltools [DEBUG] - Downcast const op 48_begin_0 data int64 as int32
# 2023-12-22 17:16:58,269 coremltools [DEBUG] - Downcast const op 48_begin_0 data int64 as int32
# 2023-12-22 17:16:58,270 coremltools [DEBUG] - Downcast const op 48_end_0 data int64 as int32
# 2023-12-22 17:16:58,270 coremltools [DEBUG] - Downcast const op 48_end_0 data int64 as int32
# 2023-12-22 17:16:58,270 coremltools [INFO] - Performing pass: "common::fuse_conv_scale"
# 2023-12-22 17:16:58,271 coremltools [INFO] - Performing pass: "common::fuse_conv_bias"
# 2023-12-22 17:16:58,271 coremltools [INFO] - Performing pass: "common::fuse_onehot_matmul_to_gather"
# 2023-12-22 17:16:58,272 coremltools [INFO] - Performing pass: "common::fuse_layernorm_or_instancenorm"
# 2023-12-22 17:16:58,273 coremltools [DEBUG] - Block before fuse_layernorm_or_instancenorm transform:
# function[CoreML5](%x: (1, 6, 1, fp32)(Tensor)) {
#   block5() {
#     %x_batch_first_transpose: (6, 1, 1, fp32)(Tensor) = transpose(x=%x, perm=[1, 0, 2], name="x_batch_first_transpose")
#     %out_batch_first_0: (6, 1, 50, fp32)(Tensor), %out_batch_first_1: (1, 50, fp32)(Tensor), %out_batch_first_2: (1, 50, fp32)(Tensor) = lstm(x=%x_batch_first_transpose, initial_h=%out_batch_first_lstm_h0_squeeze, initial_c=%out_batch_first_lstm_c0_squeeze, weight_ih=%concat_1, weight_hh=%concat_2, bias=%concat_0, direction="forward", output_sequence=True, recurrent_activation="sigmoid", cell_activation="tanh", activation="tanh", name="out_batch_first")
#     %out: (1, 6, 50, fp32)(Tensor) = transpose(x=%out_batch_first_0, perm=[1, 0, 2], name="out")
#     %48: (1, 50, fp32)(Tensor) = slice_by_index(x=%out, begin=[0, -1, 0], end=[1, 6, 50], end_mask=[True, True, True], squeeze_mask=[False, True, False], name="48")
#     %linear_0: (1, 3, fp32)(Tensor) = linear(x=%48, weight=%fc.weight, bias=[0.07220993936061859, -0.009139922447502613, -0.10473349690437317], name="linear_0")
#   } -> (%linear_0)
# }
#
# 2023-12-22 17:16:58,273 coremltools [DEBUG] - Block after fuse_layernorm_or_instancenorm transform:
# function[CoreML5](%x: (1, 6, 1, fp32)(Tensor)) {
#   block5() {
#     %x_batch_first_transpose: (6, 1, 1, fp32)(Tensor) = transpose(x=%x, perm=[1, 0, 2], name="x_batch_first_transpose")
#     %out_batch_first_0: (6, 1, 50, fp32)(Tensor), %out_batch_first_1: (1, 50, fp32)(Tensor), %out_batch_first_2: (1, 50, fp32)(Tensor) = lstm(x=%x_batch_first_transpose, initial_h=%out_batch_first_lstm_h0_squeeze, initial_c=%out_batch_first_lstm_c0_squeeze, weight_ih=%concat_1, weight_hh=%concat_2, bias=%concat_0, direction="forward", output_sequence=True, recurrent_activation="sigmoid", cell_activation="tanh", activation="tanh", name="out_batch_first")
#     %out: (1, 6, 50, fp32)(Tensor) = transpose(x=%out_batch_first_0, perm=[1, 0, 2], name="out")
#     %48: (1, 50, fp32)(Tensor) = slice_by_index(x=%out, begin=[0, -1, 0], end=[1, 6, 50], end_mask=[True, True, True], squeeze_mask=[False, True, False], name="48")
#     %linear_0: (1, 3, fp32)(Tensor) = linear(x=%48, weight=%fc.weight, bias=[0.07220993936061859, -0.009139922447502613, -0.10473349690437317], name="linear_0")
#   } -> (%linear_0)
# }
#
# 2023-12-22 17:16:58,274 coremltools [INFO] - Performing pass: "common::fuse_elementwise_to_batchnorm"
# 2023-12-22 17:16:58,275 coremltools [INFO] - Performing pass: "common::fuse_reduce_mean"
# 2023-12-22 17:16:58,275 coremltools [INFO] - Performing pass: "common::fuse_conv_batchnorm"
# 2023-12-22 17:16:58,275 coremltools [INFO] - Performing pass: "common::fuse_conv_scale"
# 2023-12-22 17:16:58,276 coremltools [INFO] - Performing pass: "common::fuse_conv_bias"
# 2023-12-22 17:16:58,276 coremltools [INFO] - Performing pass: "common::fuse_conv_batchnorm"
# 2023-12-22 17:16:58,277 coremltools [INFO] - Performing pass: "common::detect_concat_interleave"
# 2023-12-22 17:16:58,277 coremltools [INFO] - Performing pass: "common::concat_to_pixel_shuffle"
# 2023-12-22 17:16:58,277 coremltools [INFO] - Performing pass: "common::fuse_prelu"
# 2023-12-22 17:16:58,278 coremltools [INFO] - Adding op 'neg' of type mul
# 2023-12-22 17:16:58,278 coremltools [DEBUG] - Adding const op 'neg_y_0'
# 2023-12-22 17:16:58,278 coremltools [INFO] - Adding op 'neg_y_0' of type const
# 2023-12-22 17:16:58,279 coremltools [INFO] - Adding op 'relu1' of type relu
# 2023-12-22 17:16:58,279 coremltools [INFO] - Adding op 'alpha_mul' of type mul
# 2023-12-22 17:16:58,279 coremltools [DEBUG] - Adding const op 'alpha_mul_y_0'
# 2023-12-22 17:16:58,280 coremltools [INFO] - Adding op 'alpha_mul_y_0' of type const
# 2023-12-22 17:16:58,280 coremltools [DEBUG] - Downcast const op alpha_mul_y_0 data fp64 as fp32
# 2023-12-22 17:16:58,280 coremltools [DEBUG] - Downcast const op alpha_mul_y_0 data fp64 as fp32
# 2023-12-22 17:16:58,281 coremltools [INFO] - Adding op 'relu2' of type relu
# 2023-12-22 17:16:58,281 coremltools [INFO] - Adding op 'out_op' of type add
# 2023-12-22 17:16:58,282 coremltools [INFO] - Adding op 'transpose' of type transpose
# 2023-12-22 17:16:58,282 coremltools [DEBUG] - Adding const op 'transpose_perm_0'
# 2023-12-22 17:16:58,282 coremltools [INFO] - Adding op 'transpose_perm_0' of type const
# 2023-12-22 17:16:58,283 coremltools [DEBUG] - Downcast const op transpose_perm_0 data int64 as int32
# 2023-12-22 17:16:58,283 coremltools [DEBUG] - Downcast const op transpose_perm_0 data int64 as int32
# 2023-12-22 17:16:58,283 coremltools [INFO] - Adding op 'neg' of type mul
# 2023-12-22 17:16:58,284 coremltools [DEBUG] - Adding const op 'neg_y_1'
# 2023-12-22 17:16:58,284 coremltools [INFO] - Adding op 'neg_y_1' of type const
# 2023-12-22 17:16:58,284 coremltools [INFO] - Adding op 'relu1' of type relu
# 2023-12-22 17:16:58,285 coremltools [INFO] - Adding op 'alpha_mul' of type mul
# 2023-12-22 17:16:58,285 coremltools [DEBUG] - Adding const op 'alpha_mul_y_1'
# 2023-12-22 17:16:58,285 coremltools [INFO] - Adding op 'alpha_mul_y_1' of type const
# 2023-12-22 17:16:58,286 coremltools [DEBUG] - Downcast const op alpha_mul_y_1 data fp64 as fp32
# 2023-12-22 17:16:58,286 coremltools [DEBUG] - Downcast const op alpha_mul_y_1 data fp64 as fp32
# 2023-12-22 17:16:58,286 coremltools [INFO] - Adding op 'relu2' of type relu
# 2023-12-22 17:16:58,287 coremltools [INFO] - Adding op 'out_op' of type add
# 2023-12-22 17:16:58,287 coremltools [INFO] - Performing pass: "common::prelu_to_lrelu"
# 2023-12-22 17:16:58,288 coremltools [INFO] - Performing pass: "common::merge_consecutive_relus"
# 2023-12-22 17:16:58,288 coremltools [INFO] - Performing pass: "common::merge_consecutive_reshapes"
# 2023-12-22 17:16:58,289 coremltools [INFO] - Performing pass: "common::merge_consecutive_transposes"
# 2023-12-22 17:16:58,289 coremltools [INFO] - Performing pass: "common::expand_high_rank_reshape_and_transpose"
# 2023-12-22 17:16:58,291 coremltools [INFO] - Performing pass: "common::reduce_transposes"
# 2023-12-22 17:16:58,291 coremltools [INFO] - Adding op 'identity_1' of type identity
# 2023-12-22 17:16:58,292 coremltools [DEBUG] - Block before optimize transpose transform:
# function[CoreML5](%x: (1, 6, 1, fp32)(Tensor)) {
#   block5() {
#     %x_batch_first_transpose: (6, 1, 1, fp32)(Tensor) = transpose(x=%x, perm=[1, 0, 2], name="x_batch_first_transpose")
#     %out_batch_first_0: (6, 1, 50, fp32)(Tensor), %out_batch_first_1: (1, 50, fp32)(Tensor), %out_batch_first_2: (1, 50, fp32)(Tensor) = lstm(x=%x_batch_first_transpose, initial_h=%out_batch_first_lstm_h0_squeeze, initial_c=%out_batch_first_lstm_c0_squeeze, weight_ih=%concat_1, weight_hh=%concat_2, bias=%concat_0, direction="forward", output_sequence=True, recurrent_activation="sigmoid", cell_activation="tanh", activation="tanh", name="out_batch_first")
#     %out: (1, 6, 50, fp32)(Tensor) = transpose(x=%out_batch_first_0, perm=[1, 0, 2], name="out")
# ...
# 2023-12-22 17:16:58,382 coremltools [INFO] - Removing op "split_1_split_sizes_0" (type: const)
# 2023-12-22 17:16:58,383 coremltools [INFO] - Removing op "concat_0_interleave_0" (type: const)
# 2023-12-22 17:16:58,383 coremltools [INFO] - Removing op "concat_0_axis_0" (type: const)
# 2023-12-22 17:16:58,383 coremltools [INFO] - Removing op "split_0_3" (type: const)
# 2023-12-22 17:16:58,383 coremltools [INFO] - Removing op "split_0_2" (type: const)
# 2023-12-22 17:16:58,383 coremltools [INFO] - Removing op "split_0_1" (type: const)
# 2023-12-22 17:16:58,383 coremltools [INFO] - Removing op "split_0_0" (type: const)
# 2023-12-22 17:16:58,384 coremltools [INFO] - Removing op "split_0_axis_0" (type: const)
# 2023-12-22 17:16:58,384 coremltools [INFO] - Removing op "split_0_split_sizes_0" (type: const)
# 2023-12-22 17:16:58,384 coremltools [INFO] - Removing op "add_0" (type: const)
# 2023-12-22 17:16:58,384 coremltools [INFO] - Removing op "hx" (type: const)
# 2023-12-22 17:16:58,384 coremltools [INFO] - Removing op "hx.1" (type: const)
# 2023-12-22 17:16:58,384 coremltools [INFO] - Removing op "lstm.weight_ih_l0" (type: const)
# 2023-12-22 17:16:58,384 coremltools [INFO] - Removing op "lstm.weight_hh_l0" (type: const)
# 2023-12-22 17:16:58,385 coremltools [INFO] - Removing op "lstm.bias_ih_l0" (type: const)
# 2023-12-22 17:16:58,385 coremltools [INFO] - Removing op "lstm.bias_hh_l0" (type: const)
# 2023-12-22 17:16:58,385 coremltools [INFO] - Performing pass: "common::dead_code_elimination"
# 2023-12-22 17:16:58,385 coremltools [INFO] - Performing pass: "common::const_elimination"
# 2023-12-22 17:16:58,385 coremltools [INFO] - Adding op 'fc.weight_to_fp16' of type const
# 2023-12-22 17:16:58,386 coremltools [DEBUG] - Num ops affected in replacing var: 1
# 2023-12-22 17:16:58,386 coremltools [INFO] - Adding op 'fc.bias_to_fp16' of type const
# 2023-12-22 17:16:58,386 coremltools [DEBUG] - Num ops affected in replacing var: 1
# 2023-12-22 17:16:58,387 coremltools [INFO] - Performing pass: "common::cast_optimization"
# 2023-12-22 17:16:58,387 coremltools [DEBUG] - Num ops affected in replacing var: 1
# 2023-12-22 17:16:58,387 coremltools [DEBUG] - Num ops affected in replacing var: 1
# 2023-12-22 17:16:58,388 coremltools [INFO] - Performing pass: "common::dead_code_elimination"
# 2023-12-22 17:16:58,388 coremltools [INFO] - Removing op "fc.bias_to_fp16_dtype_0" (type: const)
# 2023-12-22 17:16:58,388 coremltools [INFO] - Removing op "fc.weight_to_fp16_dtype_0" (type: const)
# 2023-12-22 17:16:58,388 coremltools [INFO] - Removing op "48_cast_fp16_to_fp32_to_fp16_dtype_0" (type: const)
# 2023-12-22 17:16:58,388 coremltools [INFO] - Removing op "48_cast_fp16_to_fp32" (type: cast)
# 2023-12-22 17:16:58,389 coremltools [INFO] - Removing op "48_cast_fp16_to_fp32_dtype_0" (type: const)
# 2023-12-22 17:16:58,389 coremltools [INFO] - Removing op "out_cast_fp16_to_fp32_to_fp16_dtype_0" (type: const)
# 2023-12-22 17:16:58,389 coremltools [INFO] - Removing op "out_cast_fp16_to_fp32" (type: cast)
# 2023-12-22 17:16:58,389 coremltools [INFO] - Removing op "out_cast_fp16_to_fp32_dtype_0" (type: const)
# 2023-12-22 17:16:58,390 coremltools [INFO] - Removing op "fc.weight" (type: const)
# 2023-12-22 17:16:58,390 coremltools [INFO] - Removing op "fc.bias" (type: const)
# 2023-12-22 17:16:58,390 coremltools [INFO] - Performing pass: "common::const_elimination"
# 2023-12-22 17:16:58,390 coremltools [INFO] - Performing pass: "common::const_deduplication"
# 2023-12-22 17:16:58,391 coremltools [INFO] - Performing pass: "common::dead_code_elimination"
# 2023-12-22 17:16:58,391 coremltools [INFO] - Performing pass: "common::merge_tensorwise_affine_dequantize_with_consecutive_ops"
# 2023-12-22 17:16:58,391 coremltools [INFO] - Performing pass: "common::loop_invariant_elimination"
# 2023-12-22 17:16:58,392 coremltools [INFO] - Performing pass: "common::noop_elimination"
# 2023-12-22 17:16:58,392 coremltools [INFO] - Performing pass: "common::dedup_op_and_var_names"
# 2023-12-22 17:16:58,392 coremltools [INFO] - Performing pass: "common::reduce_transposes"
# 2023-12-22 17:16:58,393 coremltools [INFO] - Adding op 'identity_2' of type identity
# 2023-12-22 17:16:58,393 coremltools [DEBUG] - Block before optimize transpose transform:
# function[CoreML5](%x: (1, 6, 1, fp32)(Tensor)) {
#   block5() {
#     %x_to_fp16: (1, 6, 1, fp16)(Tensor) = cast(x=%x, dtype="fp16", name="x_to_fp16")
#     %x_batch_first_transpose_cast_fp16: (6, 1, 1, fp16)(Tensor) = transpose(x=%x_to_fp16, perm=[1, 0, 2], name="x_batch_first_transpose_cast_fp16")
#     %x_batch_first_transpose_cast_fp16_to_fp32: (6, 1, 1, fp32)(Tensor) = cast(x=%x_batch_first_transpose_cast_fp16, dtype="fp32", name="x_batch_first_transpose_cast_fp16_to_fp32")
#     %out_batch_first_0: (6, 1, 50, fp32)(Tensor), %out_batch_first_1: (1, 50, fp32)(Tensor), %out_batch_first_2: (1, 50, fp32)(Tensor) = lstm(x=%x_batch_first_transpose_cast_fp16_to_fp32, initial_h=%out_batch_first_lstm_h0_squeeze, initial_c=%out_batch_first_lstm_c0_squeeze, weight_ih=%concat_1, weight_hh=%concat_2, bias=%concat_0, direction="forward", output_sequence=True, recurrent_activation="sigmoid", cell_activation="tanh", activation="tanh", name="out_batch_first")
#     %out_batch_first_0_to_fp16: (6, 1, 50, fp16)(Tensor) = cast(x=%out_batch_first_0, dtype="fp16", name="out_batch_first_0_to_fp16")
#     %out_cast_fp16: (1, 6, 50, fp16)(Tensor) = transpose(x=%out_batch_first_0_to_fp16, perm=[1, 0, 2], name="out_cast_fp16")
#     %48_cast_fp16: (1, 50, fp16)(Tensor) = slice_by_index(x=%out_cast_fp16, begin=[0, -1, 0], end=[1, 6, 50], end_mask=[True, True, True], squeeze_mask=[False, True, False], name="48_cast_fp16")
#     %linear_0_cast_fp16: (1, 3, fp16)(Tensor) = linear(x=%48_cast_fp16, weight=%fc.weight_to_fp16, bias=[0.07220458984375, -0.0091400146484375, -0.104736328125], name="linear_0_cast_fp16")
#     %linear_0: (1, 3, fp32)(Tensor) = cast(x=%linear_0_cast_fp16, dtype="fp32", name="linear_0_cast_fp16_to_fp32")
#     %identity_2: (1, 3, fp32)(Tensor) = identity(x=%linear_0, name="identity_2")
#   } -> (%identity_2)
# }
#
# 2023-12-22 17:16:58,393 coremltools [DEBUG] - Block after optimize transpose transform:
# function[CoreML5](%x: (1, 6, 1, fp32)(Tensor)) {
#   block5() {
#     %x_to_fp16: (1, 6, 1, fp16)(Tensor) = cast(x=%x, dtype="fp16", name="x_to_fp16")
#     %x_batch_first_transpose_cast_fp16: (6, 1, 1, fp16)(Tensor) = transpose(x=%x_to_fp16, perm=[1, 0, 2], name="x_batch_first_transpose_cast_fp16")
#     %x_batch_first_transpose_cast_fp16_to_fp32: (6, 1, 1, fp32)(Tensor) = cast(x=%x_batch_first_transpose_cast_fp16, dtype="fp32", name="x_batch_first_transpose_cast_fp16_to_fp32")
#     %out_batch_first_0: (6, 1, 50, fp32)(Tensor), %out_batch_first_1: (1, 50, fp32)(Tensor), %out_batch_first_2: (1, 50, fp32)(Tensor) = lstm(x=%x_batch_first_transpose_cast_fp16_to_fp32, initial_h=%out_batch_first_lstm_h0_squeeze, initial_c=%out_batch_first_lstm_c0_squeeze, weight_ih=%concat_1, weight_hh=%concat_2, bias=%concat_0, direction="forward", output_sequence=True, recurrent_activation="sigmoid", cell_activation="tanh", activation="tanh", name="out_batch_first")
#     %out_batch_first_0_to_fp16: (6, 1, 50, fp16)(Tensor) = cast(x=%out_batch_first_0, dtype="fp16", name="out_batch_first_0_to_fp16")
#     %out_cast_fp16: (1, 6, 50, fp16)(Tensor) = transpose(x=%out_batch_first_0_to_fp16, perm=[1, 0, 2], name="out_cast_fp16")
#     %48_cast_fp16: (1, 50, fp16)(Tensor) = slice_by_index(x=%out_cast_fp16, begin=[0, -1, 0], end=[1, 6, 50], end_mask=[True, True, True], squeeze_mask=[False, True, False], name="48_cast_fp16")
#     %linear_0_cast_fp16: (1, 3, fp16)(Tensor) = linear(x=%48_cast_fp16, weight=%fc.weight_to_fp16, bias=[0.07220458984375, -0.0091400146484375, -0.104736328125], name="linear_0_cast_fp16")
#     %linear_0: (1, 3, fp32)(Tensor) = cast(x=%linear_0_cast_fp16, dtype="fp32", name="linear_0_cast_fp16_to_fp32")
#   } -> (%linear_0)
# }
#
# 2023-12-22 17:16:58,394 coremltools [DEBUG] - Downcast const op x_batch_first_transpose_perm_0 data int64 as int32
# 2023-12-22 17:16:58,394 coremltools [DEBUG] - Downcast const op x_batch_first_transpose_perm_0 data int64 as int32
# 2023-12-22 17:16:58,395 coremltools [DEBUG] - Downcast const op out_perm_0 data int64 as int32
# 2023-12-22 17:16:58,395 coremltools [DEBUG] - Downcast const op out_perm_0 data int64 as int32
# 2023-12-22 17:16:58,395 coremltools [DEBUG] - Downcast const op 48_begin_0 data int64 as int32
# 2023-12-22 17:16:58,395 coremltools [DEBUG] - Downcast const op 48_begin_0 data int64 as int32
# 2023-12-22 17:16:58,396 coremltools [DEBUG] - Downcast const op 48_end_0 data int64 as int32
# 2023-12-22 17:16:58,396 coremltools [DEBUG] - Downcast const op 48_end_0 data int64 as int32
# 2023-12-22 17:16:58,397 coremltools [INFO] - Performing pass: "common::remove_redundant_ops"
# 2023-12-22 17:16:58,397 coremltools [INFO] - Performing pass: "common::topological_reorder"
# 2023-12-22 17:16:58,397 coremltools [INFO] - Adding op 'cast_0' of type cast
# 2023-12-22 17:16:58,397 coremltools [DEBUG] - Num ops affected in replacing var: 0
# 2023-12-22 17:16:58,398 coremltools [INFO] - Adding op 'transpose_0' of type transpose
# 2023-12-22 17:16:58,398 coremltools [DEBUG] - Num ops affected in replacing var: 1
# 2023-12-22 17:16:58,398 coremltools [INFO] - Adding op 'cast_1' of type cast
# 2023-12-22 17:16:58,398 coremltools [DEBUG] - Num ops affected in replacing var: 2
# 2023-12-22 17:16:58,399 coremltools [INFO] - Adding op 'cast_2' of type cast
# 2023-12-22 17:16:58,399 coremltools [DEBUG] - Num ops affected in replacing var: 1
# 2023-12-22 17:16:58,399 coremltools [INFO] - Adding op 'transpose_1' of type transpose
# 2023-12-22 17:16:58,400 coremltools [DEBUG] - Num ops affected in replacing var: 2
# 2023-12-22 17:16:58,400 coremltools [INFO] - Adding op 'cast_3' of type cast
# 2023-12-22 17:16:58,400 coremltools [DEBUG] - Num ops affected in replacing var: 2
# 2023-12-22 17:16:58,401 coremltools [INFO] - Performing pass: "common::dead_code_elimination"
# Running MIL default pipeline: 100%|██████████| 71/71 [00:00<00:00, 354.17 passes/s]
# 2023-12-22 17:16:58,401 coremltools [DEBUG] - Program after default pipeline:
# main[CoreML5](%x: (1, 6, 1, fp32)(Tensor)) {
#   block5() {
#     %cast_3: (1, 6, 1, fp16)(Tensor) = cast(x=%x, dtype="fp16", name="cast_3")
#     %transpose_1: (6, 1, 1, fp16)(Tensor) = transpose(x=%cast_3, perm=[1, 0, 2], name="transpose_1")
#     %cast_2: (6, 1, 1, fp32)(Tensor) = cast(x=%transpose_1, dtype="fp32", name="cast_2")
#     %out_batch_first_0: (6, 1, 50, fp32)(Tensor), %out_batch_first_1: (1, 50, fp32)(Tensor), %out_batch_first_2: (1, 50, fp32)(Tensor) = lstm(x=%cast_2, initial_h=%out_batch_first_lstm_h0_squeeze, initial_c=%out_batch_first_lstm_c0_squeeze, weight_ih=%concat_1, weight_hh=%concat_2, bias=%concat_0, direction="forward", output_sequence=True, recurrent_activation="sigmoid", cell_activation="tanh", activation="tanh", name="out_batch_first")
#     %cast_1: (6, 1, 50, fp16)(Tensor) = cast(x=%out_batch_first_0, dtype="fp16", name="cast_1")
#     %transpose_0: (1, 6, 50, fp16)(Tensor) = transpose(x=%cast_1, perm=[1, 0, 2], name="transpose_0")
#     %48_cast_fp16: (1, 50, fp16)(Tensor) = slice_by_index(x=%transpose_0, begin=[0, -1, 0], end=[1, 6, 50], end_mask=[True, True, True], squeeze_mask=[False, True, False], name="48_cast_fp16")
#     %linear_0_cast_fp16: (1, 3, fp16)(Tensor) = linear(x=%48_cast_fp16, weight=%fc.weight_to_fp16, bias=[0.07220458984375, -0.0091400146484375, -0.104736328125], name="linear_0_cast_fp16")
#     %linear_0: (1, 3, fp32)(Tensor) = cast(x=%linear_0_cast_fp16, dtype="fp32", name="cast_0")
#   } -> (%linear_0)
# }
#
# 2023-12-22 17:16:58,402 coremltools [DEBUG] - Program before backend_mlprogram pipeline:
# main[CoreML5](%x: (1, 6, 1, fp32)(Tensor)) {
#   block5() {
#     %cast_3: (1, 6, 1, fp16)(Tensor) = cast(x=%x, dtype="fp16", name="cast_3")
#     %transpose_1: (6, 1, 1, fp16)(Tensor) = transpose(x=%cast_3, perm=[1, 0, 2], name="transpose_1")
#     %cast_2: (6, 1, 1, fp32)(Tensor) = cast(x=%transpose_1, dtype="fp32", name="cast_2")
#     %out_batch_first_0: (6, 1, 50, fp32)(Tensor), %out_batch_first_1: (1, 50, fp32)(Tensor), %out_batch_first_2: (1, 50, fp32)(Tensor) = lstm(x=%cast_2, initial_h=%out_batch_first_lstm_h0_squeeze, initial_c=%out_batch_first_lstm_c0_squeeze, weight_ih=%concat_1, weight_hh=%concat_2, bias=%concat_0, direction="forward", output_sequence=True, recurrent_activation="sigmoid", cell_activation="tanh", activation="tanh", name="out_batch_first")
#     %cast_1: (6, 1, 50, fp16)(Tensor) = cast(x=%out_batch_first_0, dtype="fp16", name="cast_1")
#     %transpose_0: (1, 6, 50, fp16)(Tensor) = transpose(x=%cast_1, perm=[1, 0, 2], name="transpose_0")
#     %48_cast_fp16: (1, 50, fp16)(Tensor) = slice_by_index(x=%transpose_0, begin=[0, -1, 0], end=[1, 6, 50], end_mask=[True, True, True], squeeze_mask=[False, True, False], name="48_cast_fp16")
#     %linear_0_cast_fp16: (1, 3, fp16)(Tensor) = linear(x=%48_cast_fp16, weight=%fc.weight_to_fp16, bias=[0.07220458984375, -0.0091400146484375, -0.104736328125], name="linear_0_cast_fp16")
#     %linear_0: (1, 3, fp32)(Tensor) = cast(x=%linear_0_cast_fp16, dtype="fp32", name="cast_0")
#   } -> (%linear_0)
# }
#
# Running MIL backend_mlprogram pipeline:   0%|          | 0/12 [00:00<?, ? passes/s]2023-12-22 17:16:58,402 coremltools [INFO] - Performing pass: "common::const_elimination"
# 2023-12-22 17:16:58,403 coremltools [INFO] - Performing pass: "mil_backend::adjust_io_to_supported_types"
# 2023-12-22 17:16:58,403 coremltools [INFO] - Performing pass: "mil_backend::insert_image_preprocessing_ops"
# 2023-12-22 17:16:58,403 coremltools [INFO] - Performing pass: "mil_backend::fuse_activation_silu"
# 2023-12-22 17:16:58,403 coremltools [INFO] - Performing pass: "mil_backend::fuse_pow2_sqrt"
# 2023-12-22 17:16:58,404 coremltools [INFO] - Performing pass: "common::const_elimination"
# 2023-12-22 17:16:58,404 coremltools [INFO] - Performing pass: "common::const_deduplication"
# 2023-12-22 17:16:58,404 coremltools [INFO] - Performing pass: "common::cast_optimization"
# 2023-12-22 17:16:58,405 coremltools [INFO] - Performing pass: "common::dead_code_elimination"
# 2023-12-22 17:16:58,405 coremltools [INFO] - Performing pass: "mil_backend::sanitize_name_strings"
# 2023-12-22 17:16:58,405 coremltools [INFO] - Performing pass: "common::dedup_op_and_var_names"
# 2023-12-22 17:16:58,405 coremltools [INFO] - Performing pass: "nn_backend::handle_unused_inputs"
# Running MIL backend_mlprogram pipeline: 100%|██████████| 12/12 [00:00<00:00, 3776.95 passes/s]
# 2023-12-22 17:16:58,406 coremltools [DEBUG] - Program after backend_mlprogram pipeline:
# main[CoreML5](%x: (1, 6, 1, fp32)(Tensor)) {
#   block5() {
#     %cast_3: (1, 6, 1, fp16)(Tensor) = cast(x=%x, dtype="fp16", name="cast_3")
#     %transpose_1: (6, 1, 1, fp16)(Tensor) = transpose(x=%cast_3, perm=[1, 0, 2], name="transpose_1")
#     %cast_2: (6, 1, 1, fp32)(Tensor) = cast(x=%transpose_1, dtype="fp32", name="cast_2")
#     %out_batch_first_0: (6, 1, 50, fp32)(Tensor), %out_batch_first_1: (1, 50, fp32)(Tensor), %out_batch_first_2: (1, 50, fp32)(Tensor) = lstm(x=%cast_2, initial_h=%out_batch_first_lstm_h0_squeeze, initial_c=%out_batch_first_lstm_c0_squeeze, weight_ih=%concat_1, weight_hh=%concat_2, bias=%concat_0, direction="forward", output_sequence=True, recurrent_activation="sigmoid", cell_activation="tanh", activation="tanh", name="out_batch_first")
#     %cast_1: (6, 1, 50, fp16)(Tensor) = cast(x=%out_batch_first_0, dtype="fp16", name="cast_1")
#     %transpose_0: (1, 6, 50, fp16)(Tensor) = transpose(x=%cast_1, perm=[1, 0, 2], name="transpose_0")
#     %var_48_cast_fp16: (1, 50, fp16)(Tensor) = slice_by_index(x=%transpose_0, begin=[0, -1, 0], end=[1, 6, 50], end_mask=[True, True, True], squeeze_mask=[False, True, False], name="op_48_cast_fp16")
#     %linear_0_cast_fp16: (1, 3, fp16)(Tensor) = linear(x=%var_48_cast_fp16, weight=%fc_weight_to_fp16, bias=[0.07220458984375, -0.0091400146484375, -0.104736328125], name="linear_0_cast_fp16")
#     %linear_0: (1, 3, fp32)(Tensor) = cast(x=%linear_0_cast_fp16, dtype="fp32", name="cast_0")
#   } -> (%linear_0)
# }
# Features(x) Features(linear_0)

# %%
example_input_test_trace.numpy().shape
# Out:
# (1, 6, 1)

# %%
# test inference using converted coreml model
coreml_pred = model_ct.predict({"x": example_input_test_trace.numpy()})['linear_0']
np.argmax(coreml_pred, axis=1)

# save the converted coreml model
model_ct.save("lstm_model.mlpackage")

# %%
# Out:
# array([0])

# %%
# Define input / output names
input_names = ["seq_input"]
output_names = ["my_output"]

# Convert the PyTorch model to ONNX
torch.onnx.export(model,
                  (example_input_for_trace,),
                  "lstm_model.onnx",
                  verbose=False,
                  input_names=input_names,
                  output_names=output_names,
                  dynamic_axes={'seq_input' : {0: 'batch'},    # variable length axes
                                'my_output' : {0: 'batch'}}
                                )
# Out:
# /opt/homebrew/anaconda3/envs/onnx_on_device/lib/python3.10/site-packages/torch/onnx/symbolic_opset9.py:4661: UserWarning: Exporting a model to ONNX with a batch_size other than 1, with a variable length with LSTM can cause an error when running the ONNX model with a different batch size. Make sure to save the model with a batch size of 1, or define the initial states (h0/c0) as inputs of the model.
#   warnings.warn(

# %%
import onnx
import onnxruntime as ort

# Load the ONNX model
model = onnx.load("lstm_model.onnx")
onnx.checker.check_model(model)

ort_session = ort.InferenceSession("lstm_model.onnx")

seq = example_input_for_trace[:1].numpy()

onnx_pred = ort_session.run(
    ["my_output"],
    {"seq_input": seq},
)
