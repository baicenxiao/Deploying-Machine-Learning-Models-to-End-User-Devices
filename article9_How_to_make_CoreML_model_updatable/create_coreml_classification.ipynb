# %%
import torch
import torch.optim as optim
import torch.nn as nn
import coremltools as ct

# Define a simple neural network with two layers
class SimpleClassificationModel(nn.Module):
    def __init__(self):
        super(SimpleClassificationModel, self).__init__()
        self.layer1 = nn.Linear(3, 100) # 3 inputs, 10 outputs
        self.layer2 = nn.Linear(100, 5)  # 10 inputs, 10 output

    def forward(self, x):
        x = torch.relu(self.layer1(x))
        x = self.layer2(x)
        return x

# Create the model
model = SimpleClassificationModel()

# Create a sample input tensor
sample_input = torch.rand(1, 3)  # Adjust the shape according to your model's input

# Trace the model with a sample input
traced_model = torch.jit.trace(model, sample_input)

# Convert the traced model to Core ML format
input_features = [ct.TensorType(shape=(1, 3))]
output_features = ["output"]
mlmodel = ct.convert(
    traced_model,
    inputs=input_features,
    convert_to="neuralnetwork"
)
mlmodel.save("classification.mlmodel")
# Out:
# Model is not in eval mode. Consider calling '.eval()' on your model prior to conversion
# Converting PyTorch Frontend ==> MIL Ops:  67%|██████▋   | 2/3 [00:00<00:00, 2418.16 ops/s]
# Running MIL frontend_pytorch pipeline: 100%|██████████| 5/5 [00:00<00:00, 13797.05 passes/s]
# Running MIL default pipeline: 100%|██████████| 69/69 [00:00<00:00, 6075.64 passes/s]
# Running MIL backend_neuralnetwork pipeline: 100%|██████████| 9/9 [00:00<00:00, 40897.87 passes/s]
# Translating MIL ==> NeuralNetwork Ops: 100%|██████████| 7/7 [00:00<00:00, 4137.56 ops/s]

# %%
import coremltools
from coremltools.models.neural_network import NeuralNetworkBuilder, SgdParams, AdamParams
from coremltools.models import datatypes
import numpy as np

spec = coremltools.utils.load_spec('classification.mlmodel')

builder = coremltools.models.neural_network.NeuralNetworkBuilder(spec=spec)

builder.inspect_layers(last=6)
builder.inspect_output_features()
# Out:
# [Id: 2], Name: linear_1 (Type: innerProduct)
#           Updatable: False
#           Input blobs: ['input']
#           Output blobs: ['linear_1']
# [Id: 1], Name: input (Type: activation)
#           Updatable: False
#           Input blobs: ['linear_0']
#           Output blobs: ['input']
# [Id: 0], Name: linear_0 (Type: innerProduct)
#           Updatable: False
#           Input blobs: ['x']
#           Output blobs: ['linear_0']
# [Id: 0] Name: linear_1
#           Type: multiArrayType {
#   dataType: FLOAT32
# }

# %%
# Build neural networks using the model specification
builder = NeuralNetworkBuilder(spec=spec)

# Make layers updatable
builder.make_updatable(['linear_0', 'linear_1'])

builder.add_softmax(name='output_prob', input_name='linear_1', output_name='output_prob')
builder.set_categorical_cross_entropy_loss(name='lossLayer', input='output_prob')


# # Manually add a mean squared error loss layer
# feature = ('linear_1', datatypes.Array(1))
# builder.set_mean_squared_error_loss(name='lossLayer', input_feature=feature)


# Define the optimizer (SGD in this example)
# sgd_params = SgdParams(lr=0.001, batch=16)  # Adjust learning rate and batch size as needed
# builder.set_sgd_optimizer(sgd_params)

# define the optimizer (Adam in this example)
adam_params = AdamParams(lr=0.01, beta1=0.9, beta2=0.999, eps=1e-8, batch=32)
builder.set_adam_optimizer(adam_params)

# Set the number of epochs
builder.set_epochs(100)

# Optionally, set descriptions for your training inputs
spec.description.trainingInput[0].shortDescription = 'Input data'
spec.description.trainingInput[1].shortDescription = 'Target output data'

spec.description.output[0].name = 'output_prob'
spec.description.output[0].shortDescription = 'Probability distribution over output classes'

# Save the updated model
updated_model = coremltools.models.MLModel(spec)
updated_model.save('updatable_classification.mlmodel')

# %%
builder.spec.description.output
# Out:
# [name: "output_prob"
# shortDescription: "Probability distribution over output classes"
# type {
#   multiArrayType {
#     dataType: FLOAT32
#   }
# }
# ]

# %%
print(builder.spec.neuralNetwork)
# Out:
# layers {
#   name: "linear_0"
#   input: "x"
#   output: "linear_0"
#   isUpdatable: true
#   innerProduct {
#     inputChannels: 3
#     outputChannels: 100
#     hasBias: true
#     weights {
#       floatValue: 0.3256458
#       floatValue: 0.24190164
#       floatValue: -0.37449187
#       floatValue: 0.20169449
#       floatValue: 0.014378905
#       floatValue: -0.0021227598
#       floatValue: -0.24283808
#       floatValue: 0.04516101
#       floatValue: -0.31663963
#       floatValue: 0.5661286
#       floatValue: 0.37231624
#       floatValue: -0.29687184
#       floatValue: 0.3901806
#       floatValue: 0.16699237
#       floatValue: 0.3044067
#       floatValue: -0.49332654
#       floatValue: -0.5229649
#       floatValue: -0.4719899
#       floatValue: -0.34196803
#       floatValue: -0.060092032
#       floatValue: 0.12668914
#       floatValue: 0.19274992
#       floatValue: 0.1888215
#       floatValue: -0.38902742
#       floatValue: 0.32209384
#       floatValue: 0.33408612
#       floatValue: -0.037695885
#       floatValue: 0.08493662
#       floatValue: -0.3085185
#       floatValue: -0.35718364
#       floatValue: -0.48851055
#       floatValue: 0.5458263
#       floatValue: 0.024518013
#       floatValue: -0.46641758
#       floatValue: 0.268367
#       floatValue: 0.5244901
#       floatValue: 0.36966705
#       floatValue: 0.15917331
#       floatValue: -0.50659966
#       floatValue: -0.43132138
#       floatValue: -0.5175622
#       floatValue: -0.50993615
#       floatValue: 0.06765312
#       floatValue: -0.49889323
#       floatValue: -0.39960644
#       floatValue: -0.22349337
#       floatValue: 0.51118934
#       floatValue: 0.4962995
#       floatValue: -0.18698528
#       floatValue: -0.5581012
#       floatValue: 0.14507079
#       floatValue: 0.42188936
#       floatValue: -0.42076445
#       floatValue: 0.4381112
#       floatValue: -0.41230828
#       floatValue: 0.056944847
#       floatValue: 0.33902866
#       floatValue: -0.085068464
#       floatValue: 0.51353574
#       floatValue: 0.507069
#       floatValue: -0.5414901
#       floatValue: 0.052681744
#       floatValue: -0.35080454
#       floatValue: -0.29733297
#       floatValue: -0.50425565
#       floatValue: -0.5078624
#       floatValue: 0.05245453
#       floatValue: 0.322237
#       floatValue: 0.10289621
#       floatValue: 0.4003892
#       floatValue: 0.02919352
#       floatValue: 0.53833854
#       floatValue: 0.09645909
#       floatValue: 0.07088131
#       floatValue: -0.51851696
#       floatValue: 0.48619854
#       floatValue: -0.45453614
#       floatValue: -0.43433827
#       floatValue: -0.5185565
#       floatValue: -0.12943009
#       floatValue: 0.25428635
#       floatValue: 0.20031995
#       floatValue: 0.34318268
#       floatValue: -0.09235364
#       floatValue: -0.038342774
#       floatValue: -0.40201396
#       floatValue: 0.08929062
#       floatValue: -0.19309598
#       floatValue: -0.12452304
#       floatValue: -0.18933699
#       floatValue: 0.4530729
#       floatValue: 0.1935193
#       floatValue: -0.38417637
#       floatValue: -0.38926038
#       floatValue: -0.00032311678
#       floatValue: 0.36225516
#       floatValue: -0.3650366
#       floatValue: -0.08237651
#       floatValue: -0.2584732
#       floatValue: 0.27642256
#       floatValue: -0.1008479
#       floatValue: 0.2012198
#       floatValue: -0.054626405
#       floatValue: 0.23481089
#       floatValue: -0.35694653
#       floatValue: -0.3305262
#       floatValue: 0.20166641
#       floatValue: 0.42018944
#       floatValue: 0.07243633
#       floatValue: 0.21079075
#       floatValue: 0.20282048
#       floatValue: 0.5106629
#       floatValue: -0.56679034
#       floatValue: 0.13503957
#       floatValue: -0.21888834
#       floatValue: -0.38906807
#       floatValue: 0.30929607
#       floatValue: -0.3508765
#       floatValue: -0.35451514
#       floatValue: 0.13424242
#       floatValue: -0.4999447
#       floatValue: -0.15059704
#       floatValue: 0.50618625
#       floatValue: 0.049235046
#       floatValue: 0.31608123
#       floatValue: -0.33424228
#       floatValue: 0.019050539
#       floatValue: 0.24781066
#       floatValue: 0.20683801
#       floatValue: -0.020020247
#       floatValue: 0.35840487
#       floatValue: -0.1657319
#       floatValue: -0.012045145
#       floatValue: 0.2582966
#       floatValue: -0.121043295
#       floatValue: -0.56957567
#       floatValue: -0.063382626
#       floatValue: -0.3834713
#       floatValue: 0.17670786
#       floatValue: -0.19264501
#       floatValue: 0.44740188
#       floatValue: -0.26108792
#       floatValue: 0.2513072
#       floatValue: 0.04028672
#       floatValue: 0.06531829
#       floatValue: 0.14302784
#       floatValue: -0.04623115
#       floatValue: 0.3928374
#       floatValue: 0.25201344
#       floatValue: 0.0013226867
#       floatValue: 0.007044971
#       floatValue: 0.35530335
#       floatValue: -0.56063545
#       floatValue: 0.23754245
#       floatValue: 0.2053181
#       floatValue: -0.53708565
#       floatValue: -0.56046516
#       floatValue: -0.15098625
#       floatValue: 0.55473435
#       floatValue: -0.33333746
#       floatValue: 0.22650725
#       floatValue: -0.19188863
#       floatValue: -0.4277373
#       floatValue: -0.37248325
#       floatValue: 0.4044848
#       floatValue: -0.561831
#       floatValue: 0.031889677
#       floatValue: -0.24483252
#       floatValue: 0.10926324
#       floatValue: 0.42923033
#       floatValue: 0.10807246
#       floatValue: 0.006458819
#       floatValue: -0.2578795
#       floatValue: -0.19319955
#       floatValue: 0.08422768
#       floatValue: 0.32266253
#       floatValue: 0.3889407
#       floatValue: 0.29177576
#       floatValue: 0.09383476
#       floatValue: 0.43557048
#       floatValue: 0.06028098
#       floatValue: 0.11336094
#       floatValue: -0.3108693
#       floatValue: 0.27088654
#       floatValue: -0.2334291
#       floatValue: 0.46291137
#       floatValue: -0.33789253
#       floatValue: 0.08296305
#       floatValue: -0.44231385
#       floatValue: 0.3765748
#       floatValue: 0.35094488
#       floatValue: -0.52029514
#       floatValue: -0.21791989
#       floatValue: -0.4942208
#       floatValue: 0.50844085
#       floatValue: -0.14493519
#       floatValue: -0.13240644
#       floatValue: 0.5074338
#       floatValue: -0.2270306
#       floatValue: 0.30228442
#       floatValue: 0.4955144
#       floatValue: -0.5736802
#       floatValue: 0.30212635
#       floatValue: 0.19782317
#       floatValue: -0.104376584
#       floatValue: -0.3087443
#       floatValue: 0.22825348
#       floatValue: 0.31003332
#       floatValue: 0.47891223
#       floatValue: 0.3912549
#       floatValue: -0.26860043
#       floatValue: -0.03660047
#       floatValue: -0.29082146
#       floatValue: -0.14663091
#       floatValue: -0.24257973
#       floatValue: -0.4899332
#       floatValue: -0.14733484
#       floatValue: -0.4605636
#       floatValue: 0.185188
#       floatValue: -0.10525307
#       floatValue: -0.13504207
#       floatValue: 0.42469168
#       floatValue: -0.55093354
#       floatValue: 0.028386235
#       floatValue: -0.18783617
#       floatValue: -0.24558616
#       floatValue: 0.4643401
#       floatValue: -0.34577078
#       floatValue: 0.27920628
#       floatValue: -0.24088895
#       floatValue: -0.04110259
#       floatValue: 0.5032456
#       floatValue: 0.14536726
#       floatValue: 0.57605493
#       floatValue: 0.57155716
#       floatValue: -0.2689384
#       floatValue: 0.5086552
#       floatValue: 0.07217723
#       floatValue: -0.47883272
#       floatValue: -0.40661013
#       floatValue: -0.33522004
#       floatValue: 0.23862582
#       floatValue: -0.5471707
#       floatValue: -0.1461379
#       floatValue: 0.06068808
#       floatValue: -0.30044726
#       floatValue: -0.09899649
#       floatValue: 0.49955475
#       floatValue: -0.3062918
#       floatValue: -0.023731649
#       floatValue: 0.021238148
#       floatValue: -0.069764614
#       floatValue: -0.28760174
#       floatValue: 0.55651784
#       floatValue: 0.14572525
#       floatValue: -0.51749885
#       floatValue: 0.3092844
#       floatValue: -0.2812074
#       floatValue: -0.50944334
#       floatValue: 0.42203814
#       floatValue: 0.47639954
#       floatValue: 0.32510972
#       floatValue: -0.2186605
#       floatValue: 0.22505331
#       floatValue: -0.46674353
#       floatValue: 0.16454268
#       floatValue: 0.55871236
#       floatValue: 0.562922
#       floatValue: 0.3121742
#       floatValue: 0.5298188
#       floatValue: 0.24285299
#       floatValue: 0.07787633
#       floatValue: -0.43315583
#       floatValue: -0.32758233
#       floatValue: 0.5007212
#       floatValue: -0.37191573
#       floatValue: 0.39846522
#       floatValue: 0.4924618
#       floatValue: 0.30680192
#       floatValue: -0.43479162
#       floatValue: -0.17254487
#       floatValue: -0.01157707
#       floatValue: -0.46947163
#       floatValue: -0.14153072
#       floatValue: 0.25537926
#       floatValue: 0.22099847
#       floatValue: -0.56301695
#       floatValue: 0.29598075
#       floatValue: 0.02814436
#       floatValue: -0.074139
#       floatValue: 0.09159237
#       floatValue: 0.29837054
#       floatValue: -0.38686857
#       floatValue: 0.34723794
#       floatValue: -0.009672582
#       floatValue: -0.45387137
#       floatValue: -0.23271793
#       floatValue: -0.14204016
#       floatValue: 0.18726677
#       floatValue: -0.20504716
#       isUpdatable: true
#     }
#     bias {
#       floatValue: 0.07939017
#       floatValue: -0.052288055
#       floatValue: -0.24935395
#       floatValue: -0.48975512
#       floatValue: 0.32405007
#       floatValue: 0.35303336
#       floatValue: 0.36955744
#       floatValue: 0.40280527
#       floatValue: 0.15248817
#       floatValue: -0.55342954
#       floatValue: 0.21349871
#       floatValue: 0.4542333
#       floatValue: -0.5737603
#       floatValue: -0.4844517
#       floatValue: 0.48750842
#       floatValue: -0.30990607
#       floatValue: -0.4305988
#       floatValue: -0.14064121
#       floatValue: -0.06925285
#       floatValue: 0.40173757
#       floatValue: -0.53046453
#       floatValue: 0.5679903
#       floatValue: 0.42605138
#       floatValue: -0.32163662
#       floatValue: -0.019677758
#       floatValue: -0.10898864
#       floatValue: -0.07115114
#       floatValue: 0.50873387
#       floatValue: 0.25954247
#       floatValue: 0.1882757
#       floatValue: -0.27870253
#       floatValue: -0.05372691
#       floatValue: 0.30160058
#       floatValue: -0.20113045
#       floatValue: -0.0810349
#       floatValue: 0.12576479
#       floatValue: -0.07206941
#       floatValue: -0.20625451
#       floatValue: -0.5684146
#       floatValue: -0.01458472
#       floatValue: 0.47502017
#       floatValue: 0.0733636
#       floatValue: 0.3566743
#       floatValue: -0.03662479
#       floatValue: -0.02713877
#       floatValue: 0.17584145
#       floatValue: 0.54029214
#       floatValue: 0.31844318
#       floatValue: 0.1565699
#       floatValue: -0.51725924
#       floatValue: -0.49137014
#       floatValue: -0.5430763
#       floatValue: -0.54221916
#       floatValue: 0.3090682
#       floatValue: -0.27447772
#       floatValue: 0.14047033
#       floatValue: -0.21748582
#       floatValue: -0.4672662
#       floatValue: -0.17634103
#       floatValue: -0.03367865
#       floatValue: -0.2547228
#       floatValue: 0.41231877
#       floatValue: 0.1470477
#       floatValue: -0.19041082
#       floatValue: -0.32520235
#       floatValue: -0.22110507
#       floatValue: 0.36640334
#       floatValue: 0.06880081
#       floatValue: 0.05292207
#       floatValue: 0.35945344
#       floatValue: 0.53418994
#       floatValue: -0.34707928
#       floatValue: 0.37056708
#       floatValue: 0.18856615
#       floatValue: 0.06344801
#       floatValue: 0.5123625
#       floatValue: 0.5638567
#       floatValue: 0.19612259
#       floatValue: 0.55168056
#       floatValue: 0.09292978
#       floatValue: 0.23335314
#       floatValue: 0.3031605
#       floatValue: -0.41203186
#       floatValue: 0.548926
#       floatValue: 0.5364189
#       floatValue: 0.22740889
#       floatValue: -0.10114011
#       floatValue: 0.29112244
#       floatValue: 0.07049233
#       floatValue: 0.35625345
#       floatValue: 0.55532527
#       floatValue: -0.4703261
#       floatValue: 0.5435231
#       floatValue: -0.46138436
#       floatValue: 0.1337251
#       floatValue: 0.48562455
#       floatValue: 0.057757616
#       floatValue: 0.476982
#       floatValue: 0.013935089
#       floatValue: -0.3953601
#       isUpdatable: true
#     }
#   }
# }
# layers {
#   name: "input"
#   input: "linear_0"
#   output: "input"
#   activation {
#     ReLU {
#     }
#   }
# }
# layers {
#   name: "linear_1"
#   input: "input"
#   output: "linear_1"
#   isUpdatable: true
#   innerProduct {
#     inputChannels: 100
#     outputChannels: 5
#     hasBias: true
#     weights {
#       floatValue: -0.09579306
#       floatValue: -0.0013184175
#       floatValue: -0.044796646
#       floatValue: -0.07657669
#       floatValue: 0.007906638
#       floatValue: 0.010414675
#       floatValue: -0.0923742
#       floatValue: -0.09404775
#       floatValue: -0.0029254556
#       floatValue: -0.017630637
#       floatValue: -0.0936824
#       floatValue: -0.026046075
#       floatValue: 0.023419857
#       floatValue: -0.08122345
#       floatValue: 0.020816706
#       floatValue: 0.007694185
#       floatValue: -0.079253055
#       floatValue: -0.097571924
#       floatValue: -0.026982628
#       floatValue: -0.010975741
#       floatValue: -0.018278852
#       floatValue: -0.025468387
#       floatValue: -0.045892667
#       floatValue: 0.027571686
#       floatValue: -0.098811865
#       floatValue: -0.013580188
#       floatValue: -0.031180106
#       floatValue: -0.06983539
#       floatValue: -0.012898266
#       floatValue: 0.08280005
#       floatValue: -0.07235291
#       floatValue: -0.0071252957
#       floatValue: 0.0935609
#       floatValue: -0.084134996
#       floatValue: -0.030557968
#       floatValue: 0.09551609
#       floatValue: 0.09581194
#       floatValue: -0.06488745
#       floatValue: 0.027075492
#       floatValue: -0.052371193
#       floatValue: 0.010169506
#       floatValue: -0.038744282
#       floatValue: 0.015489474
#       floatValue: 0.06675988
#       floatValue: -0.062057544
#       floatValue: 0.0152318105
#       floatValue: -0.0100807175
#       floatValue: -0.051173616
#       floatValue: 0.046717532
#       floatValue: -0.0025402904
#       floatValue: -0.028642103
#       floatValue: 0.0537856
#       floatValue: -0.06040386
#       floatValue: -0.06593678
#       floatValue: -0.046782423
#       floatValue: -0.028008662
#       floatValue: 0.051486082
#       floatValue: 0.050898276
#       floatValue: 0.09269931
#       floatValue: -0.08857552
#       floatValue: 0.033280782
#       floatValue: 0.026111834
#       floatValue: 0.02287928
#       floatValue: 0.04641693
#       floatValue: -0.0698653
#       floatValue: -0.049593665
#       floatValue: -0.024026573
#       floatValue: -0.061594367
#       floatValue: 0.044169597
#       floatValue: 0.015121043
#       floatValue: -0.037995912
#       floatValue: -0.08878682
#       floatValue: -0.046405017
#       floatValue: -9.2729926e-05
#       floatValue: -0.094173744
#       floatValue: 0.00782527
#       floatValue: -0.032199346
#       floatValue: -0.022466734
#       floatValue: 0.046225317
#       floatValue: 0.09200955
#       floatValue: -0.049868762
#       floatValue: -0.030263998
#       floatValue: -0.08496975
#       floatValue: 0.030114435
#       floatValue: 0.09491319
#       floatValue: 0.08418632
#       floatValue: -0.062504485
#       floatValue: -0.06924683
#       floatValue: 0.027870603
#       floatValue: 0.06276777
#       floatValue: 0.046303965
#       floatValue: 0.06543217
#       floatValue: 0.020194963
#       floatValue: 0.083006494
#       floatValue: 0.037493117
#       floatValue: 0.09777423
#       floatValue: 0.09131602
#       floatValue: -0.0022835732
#       floatValue: 0.051257275
#       floatValue: -0.0019549876
#       floatValue: -0.07450706
#       floatValue: -0.015377417
#       floatValue: -0.08742006
#       floatValue: 0.06689008
#       floatValue: 0.0026515573
#       floatValue: 0.026531704
#       floatValue: 0.08447113
#       floatValue: 0.0030105934
#       floatValue: -0.05894009
#       floatValue: -0.024848118
#       floatValue: -0.04455904
#       floatValue: 0.023871385
#       floatValue: -0.032607377
#       floatValue: -0.04745617
#       floatValue: 0.07968136
#       floatValue: 0.009522259
#       floatValue: 0.033661015
#       floatValue: 0.0014951378
#       floatValue: 0.01958803
#       floatValue: -0.05015242
#       floatValue: 0.0938145
#       floatValue: 0.07599484
#       floatValue: -0.002382122
#       floatValue: -0.098638155
#       floatValue: -0.008265063
#       floatValue: -0.01895471
#       floatValue: 0.090572186
#       floatValue: 0.08363027
#       floatValue: -0.0007005483
#       floatValue: -0.00075223297
#       floatValue: 0.08190764
#       floatValue: -0.039504815
#       floatValue: -0.07200986
#       floatValue: 0.04117077
#       floatValue: 0.08194766
#       floatValue: -0.046236765
#       floatValue: 0.012677811
#       floatValue: -0.09126874
#       floatValue: 0.03997714
#       floatValue: -0.03767444
#       floatValue: -0.057410013
#       floatValue: -0.025410607
#       floatValue: -0.085910164
#       floatValue: -0.04134947
#       floatValue: 0.046809517
#       floatValue: -0.036867067
#       floatValue: -0.036718354
#       floatValue: 0.06464585
#       floatValue: 0.005742356
#       floatValue: 0.09997714
#       floatValue: -0.055845834
#       floatValue: -0.02954755
#       floatValue: 0.09577728
#       floatValue: -0.023756303
#       floatValue: 0.09391958
#       floatValue: -0.044806268
#       floatValue: 0.031453945
#       floatValue: 0.07394571
#       floatValue: -0.0320431
#       floatValue: -0.055932175
#       floatValue: -0.09881123
#       floatValue: -0.08708242
#       floatValue: 0.03859333
#       floatValue: -0.0028415173
#       floatValue: 0.034193285
#       floatValue: -0.0015410334
#       floatValue: -0.005311094
#       floatValue: -0.01494547
#       floatValue: -0.068078496
#       floatValue: 0.08445414
#       floatValue: 0.09367495
#       floatValue: -0.00040842593
#       floatValue: -0.01189439
#       floatValue: 0.05879151
#       floatValue: 0.09717066
#       floatValue: -0.08426769
#       floatValue: -0.09403936
#       floatValue: -0.014157131
#       floatValue: 0.09091941
#       floatValue: -0.089848295
#       floatValue: -0.038604785
#       floatValue: 0.09811241
#       floatValue: 0.024621092
#       floatValue: 0.092706464
#       floatValue: 0.07433874
#       floatValue: 0.06311289
#       floatValue: -0.06486423
#       floatValue: -0.061377276
#       floatValue: -0.081542686
#       floatValue: 0.033997186
#       floatValue: -0.0016940832
#       floatValue: -0.022074878
#       floatValue: -0.003459826
#       floatValue: 0.076523475
#       floatValue: -0.03221093
#       floatValue: -0.070376955
#       floatValue: -0.076371446
#       floatValue: 0.060931496
#       floatValue: 0.0581019
#       floatValue: -0.025509752
#       floatValue: -0.09379989
#       floatValue: -0.045714855
#       floatValue: 0.06636769
#       floatValue: 0.06363272
#       floatValue: 0.0086800605
#       floatValue: -0.02469889
#       floatValue: 0.08980978
#       floatValue: 0.04051421
#       floatValue: 0.05991847
#       floatValue: -0.043870486
#       floatValue: -0.045951236
#       floatValue: -0.053736307
#       floatValue: 0.043579854
#       floatValue: 0.07913434
#       floatValue: -0.07057945
#       floatValue: -0.004058346
#       floatValue: 0.037319906
#       floatValue: 0.006012082
#       floatValue: 0.03477823
#       floatValue: -0.006965354
#       floatValue: 0.001201056
#       floatValue: 0.04867115
#       floatValue: 0.034093253
#       floatValue: -0.08761165
#       floatValue: 0.018320084
#       floatValue: 0.019998923
#       floatValue: 0.08233317
#       floatValue: -0.09248753
#       floatValue: -0.054492403
#       floatValue: 0.0038206354
#       floatValue: 0.059303053
#       floatValue: -0.06590811
#       floatValue: 0.06921435
#       floatValue: 0.019175366
#       floatValue: -0.05488546
#       floatValue: -0.0053852648
#       floatValue: 0.065660425
#       floatValue: 0.08956278
#       floatValue: -0.059651434
#       floatValue: -0.039107647
#       floatValue: 0.0117164105
#       floatValue: -0.095680036
#       floatValue: 0.033824183
#       floatValue: 0.028047718
#       floatValue: -0.02078446
#       floatValue: -0.0045158863
#       floatValue: -0.07013819
#       floatValue: -0.09543701
#       floatValue: 0.009959914
#       floatValue: -0.05505581
#       floatValue: 0.005923286
#       floatValue: -0.07366961
#       floatValue: 0.044397064
#       floatValue: 0.07379145
#       floatValue: 0.037566848
#       floatValue: -0.010627702
#       floatValue: 0.0074279457
#       floatValue: 0.015233681
#       floatValue: 0.004949048
#       floatValue: -0.058741666
#       floatValue: 0.050916858
#       floatValue: -0.005626619
#       floatValue: 0.010191537
#       floatValue: 0.08716712
#       floatValue: -0.024558857
#       floatValue: -0.014646038
#       floatValue: 0.013694957
#       floatValue: 0.046319865
#       floatValue: 0.075930364
#       floatValue: -0.066858746
#       floatValue: -0.04158629
#       floatValue: 0.09859032
#       floatValue: -0.036017813
#       floatValue: 0.032643564
#       floatValue: -0.073639944
#       floatValue: 0.049350716
#       floatValue: 0.0556973
#       floatValue: 0.06810767
#       floatValue: 0.064450644
#       floatValue: -0.0019688383
#       floatValue: -0.09656145
#       floatValue: 0.03445872
#       floatValue: 0.007354021
#       floatValue: -0.0946051
#       floatValue: 0.040276475
#       floatValue: 0.0116887465
#       floatValue: 0.0060141683
#       floatValue: -0.08074729
#       floatValue: 0.05556772
#       floatValue: -0.002353087
#       floatValue: -0.011041567
#       floatValue: -0.06102517
#       floatValue: 0.080830134
#       floatValue: -0.04889009
#       floatValue: -0.0057792664
#       floatValue: -0.05297506
#       floatValue: 0.08907368
#       floatValue: -0.009069167
#       floatValue: -0.0770545
#       floatValue: -0.01845517
#       floatValue: -0.098315395
#       floatValue: -0.044213343
#       floatValue: -0.04446733
#       floatValue: -0.011383034
#       floatValue: -0.004365124
#       floatValue: 0.088870056
#       floatValue: 0.03976468
#       floatValue: 0.0146051645
#       floatValue: -0.014749542
#       floatValue: -0.030782714
#       floatValue: 0.029564135
#       floatValue: -0.050160695
#       floatValue: -0.008672297
#       floatValue: -0.046823468
#       floatValue: -0.038949
#       floatValue: -0.079965696
#       floatValue: -0.013011888
#       floatValue: 0.057547815
#       floatValue: -0.069505475
#       floatValue: 0.035981186
#       floatValue: -0.0035048127
#       floatValue: 0.07726159
#       floatValue: -0.025813363
#       floatValue: 0.07159544
#       floatValue: -0.08101036
#       floatValue: -0.09448373
#       floatValue: 0.0057613105
#       floatValue: 0.06871421
#       floatValue: -0.017954685
#       floatValue: -0.016100623
#       floatValue: -0.02608832
#       floatValue: 0.013460115
#       floatValue: 0.070722364
#       floatValue: -0.05851407
#       floatValue: -0.08739906
#       floatValue: -0.017972961
#       floatValue: -0.014199242
#       floatValue: -0.015900314
#       floatValue: 0.055717282
#       floatValue: 0.033472337
#       floatValue: -0.04651436
#       floatValue: -0.08781489
#       floatValue: -0.027971908
#       floatValue: -0.0990945
#       floatValue: -0.040201437
#       floatValue: 0.04603929
#       floatValue: -0.09160306
#       floatValue: -0.081069276
#       floatValue: 0.06378118
#       floatValue: 0.072673045
#       floatValue: -0.028709948
#       floatValue: 0.07277871
#       floatValue: -0.091892935
#       floatValue: -0.059615385
#       floatValue: 0.055127032
#       floatValue: 0.057648845
#       floatValue: 0.00793393
#       floatValue: 0.01793535
#       floatValue: 0.05445998
#       floatValue: 0.084389575
#       floatValue: 0.02376081
#       floatValue: 0.04523181
#       floatValue: -0.012425162
#       floatValue: 0.07243573
#       floatValue: -0.082347594
#       floatValue: -0.0630875
#       floatValue: 0.02222588
#       floatValue: 0.0935489
#       floatValue: 0.028010719
#       floatValue: -0.08548903
#       floatValue: -0.09655243
#       floatValue: -0.0028054938
#       floatValue: 0.06978708
#       floatValue: 0.006025031
#       floatValue: 0.013801709
#       floatValue: -0.033940777
#       floatValue: 0.043946393
#       floatValue: -0.09245682
#       floatValue: 0.0468164
#       floatValue: -0.021611013
#       floatValue: -0.042983305
#       floatValue: 0.04538206
#       floatValue: 0.023155987
#       floatValue: 0.09171518
#       floatValue: -0.099502824
#       floatValue: 0.08629722
#       floatValue: 0.0016005039
#       floatValue: 0.037757657
#       floatValue: 0.05620096
#       floatValue: 0.07215261
#       floatValue: -0.029291376
#       floatValue: 0.019952402
#       floatValue: -0.0029176623
#       floatValue: -0.027680054
#       floatValue: 0.0627586
#       floatValue: -0.06177428
#       floatValue: -0.008291103
#       floatValue: -0.014213838
#       floatValue: 0.018627822
#       floatValue: -0.06790577
#       floatValue: 0.076171525
#       floatValue: 0.01577834
#       floatValue: -0.047432076
#       floatValue: 0.043766297
#       floatValue: 0.08043123
#       floatValue: 0.07405769
#       floatValue: -0.058570087
#       floatValue: -0.053653657
#       floatValue: 0.0299486
#       floatValue: 0.0027929172
#       floatValue: -0.038497508
#       floatValue: -0.021104977
#       floatValue: 0.054396562
#       floatValue: 0.03975577
#       floatValue: -0.076630816
#       floatValue: -0.07270138
#       floatValue: 0.028668515
#       floatValue: 0.02530665
#       floatValue: 0.028036796
#       floatValue: -0.04646304
#       floatValue: 0.009521291
#       floatValue: -0.076693855
#       floatValue: 0.08561886
#       floatValue: -0.003447868
#       floatValue: 0.08218325
#       floatValue: 0.05476027
#       floatValue: -0.06413707
#       floatValue: -0.026053645
#       floatValue: -0.060040273
#       floatValue: 0.04773415
#       floatValue: -0.05603043
#       floatValue: 0.00769677
#       floatValue: 0.0035012215
#       floatValue: 0.024551496
#       floatValue: -0.02477242
#       floatValue: -0.013396405
#       floatValue: -0.018996
#       floatValue: -0.018181816
#       floatValue: -0.022870027
#       floatValue: -0.09436673
#       floatValue: 0.0759735
#       floatValue: -0.09742781
#       floatValue: 0.09717464
#       floatValue: 0.05528567
#       floatValue: -0.0012722611
#       floatValue: 0.063231476
#       floatValue: -0.0036014542
#       floatValue: -0.011139691
#       floatValue: -0.0044390783
#       floatValue: -0.029508516
#       floatValue: -0.08912398
#       floatValue: 0.05004578
#       floatValue: 0.09046056
#       floatValue: 0.09014014
#       floatValue: -0.07044908
#       floatValue: 0.071491845
#       floatValue: -0.006463565
#       floatValue: -0.09016695
#       floatValue: -0.082278706
#       floatValue: -0.0981999
#       floatValue: -0.051770736
#       floatValue: -0.009713337
#       floatValue: -0.014016882
#       floatValue: -0.08839365
#       floatValue: -0.07200974
#       floatValue: -0.029459871
#       floatValue: 0.055157043
#       floatValue: 0.059943862
#       floatValue: -0.002293706
#       floatValue: 0.011827961
#       floatValue: -0.036264434
#       floatValue: 0.08645446
#       floatValue: 0.069229044
#       floatValue: 0.07434351
#       floatValue: 0.059900172
#       floatValue: 0.0031699985
#       floatValue: -0.013607003
#       floatValue: -0.05795584
#       floatValue: 0.04925845
#       floatValue: 0.049293302
#       floatValue: 0.00016753376
#       floatValue: 0.07303383
#       floatValue: 0.057721727
#       floatValue: 0.04882229
#       floatValue: 0.02882322
#       floatValue: -0.014581487
#       floatValue: -0.075229004
#       floatValue: 0.011567257
#       floatValue: -0.0019574165
#       floatValue: 0.034281902
#       floatValue: 0.063728936
#       floatValue: -0.008802399
#       floatValue: 0.07213389
#       floatValue: 0.028041191
#       floatValue: -0.019548357
#       floatValue: 0.049782105
#       floatValue: -0.004001841
#       floatValue: 0.013057493
#       floatValue: -0.09201608
#       floatValue: -0.088295005
#       isUpdatable: true
#     }
#     bias {
#       floatValue: 0.09088483
#       floatValue: 0.05389572
#       floatValue: -0.029887393
#       floatValue: 0.08984045
#       floatValue: 0.09989614
#       isUpdatable: true
#     }
#   }
# }
# layers {
#   name: "output_prob"
#   input: "linear_1"
#   output: "output_prob"
#   softmax {
#   }
# }
# arrayInputShapeMapping: EXACT_ARRAY_MAPPING
# imageInputShapeMapping: RANK4_IMAGE_MAPPING
# updateParams {
#   lossLayers {
#     name: "lossLayer"
#     categoricalCrossEntropyLossLayer {
#       input: "output_prob"
#       target: "output_prob_true"
#     }
#   }
#   optimizer {
#     adamOptimizer {
#       learningRate {
#         defaultValue: 0.01
#         range {
#           maxValue: 1.0
#         }
#       }
#       miniBatchSize {
#         defaultValue: 32
#         set {
#           values: 32
#         }
#       }
#       beta1 {
#         defaultValue: 0.9
#         range {
#           maxValue: 1.0
#         }
#       }
#       beta2 {
#         defaultValue: 0.999
#         range {
#           maxValue: 1.0
#         }
#       }
#       eps {
#         defaultValue: 1e-08
#         range {
#           maxValue: 1.0
#         }
#       }
#     }
#   }
#   epochs {
#     defaultValue: 100
#     set {
#       values: 100
#     }
#   }
#   shuffle {
#     defaultValue: true
#   }
# }
